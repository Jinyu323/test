# %% [markdown]
# # <center> Task 1

# %% [markdown]
# Some of the Product_URLs in the log file might have been corrupted. Write a Python (or PySpark) procedure to determine which Product_URLs are corrupted. Let us assume that if a Product_url in the log file doesn’t occur in the products table, it is regarded as corrupted. Using this procedure identify and list the corrupted URLs.  (10)

# %% [markdown]
# # <center> Answer

# %% [markdown]
# - We can utilize python and pandas package to deal with these problems. pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,built on top of the Python programming language.First, we use pd.merge (here I set the parameter "how = left",which means this function uses only keys from left frame, similar to a SQL left outer join; preserve key order) function to merge the log file and the products file. As a result, final dataframe has 216 missing values, which means there are 216 corrupted URLs. And I list the 216 corrupted URLs.

# %%
import pandas as pd
import urllib.parse
import warnings
import difflib
df_log = pd.read_csv('log2.csv')
df_product = pd.read_csv('products.csv')
df_prodect_category = pd.read_csv('product_categories.csv')

# %%
df_product = df_product.drop_duplicates(subset=['Product URL'])

# %%
df_merge = pd.merge(df_log, df_product, on="Product URL", how="left",validate='many_to_one')
df_merge['product'].isnull().sum()
# Out:
# 216

# %%
df_corrupted = df_merge[df_merge.isna().T.any()]
df_corrupted['Product URL']
# Out:
# 83      https://haier.com/refrigermtors
# 109        https://sony.comftelevisions
# 123              https://lg.com/gashers
# 171              https://leks.com/jeans
# 203      https://InstantPot.con/cookers
#                      ...
# 9729           http://nejoK.co/blenders
# 9773         https://maytag.cpm/washers
# 9845         https://guessmcom/perfumes
# 9881    https://samsuag.com/televisions
# 9951     https://InstantPotycom/cookers
# Name: Product URL, Length: 216, dtype: object

# %%
df_product.shape
# Out:
# (50, 3)

# %% [markdown]
# # <center> Task 2

# %% [markdown]
# For each corrupted URL what will you do with it? Don’t assume that for each corrupted URL the correct approach is to delete that log entry. What if the URL contained ‘.cam’ instead of ‘.com’ but otherwise corresponded with a URL in the ‘products’ table? In that case the proper approach would be to correct the URL. In other cases, the URL might be so corrupted that the best approach would be to delete that log entry (the entire row). Describe your approach to dealing with corrupted URLs. That is, describe your approach to determining that a URL is too corrupted to be rescued. It must describe a) a procedure for determining the degree to which the URL is corrupted, b) a threshold for determining in terms of this degree of corruption whether it can be corrected, and c) for those which can be corrected, identifying its corrected form. For extra credit implement this in a Python (or PySpark) program. (25 + 20 points for extra-credit)

# %% [markdown]
# # <center> Answer

# %% [markdown]
# - Correcting 216 corrupted URLs one by one is a difficult and tedious task. I wrote an algorithm to help me with this challenge.
#     - First, I utilized urllib.parse.quote function to replace special characters in URL string using the %xx escape. Thus, I got 216 strings without special characters.
#     - Second, I used difflib.SequenceMatcher function (This function quantifies the degree of similarity between two strings) to compare 216 corrupted URLs and 50 correct URLS. If similarity between two strings > 0.94, which means that the corrupted URL found its correct counterpart, I will directly replace the corrupted URL with its correct counterpart.
# - Eventually, this algorithm successfully corrected the 216 corrupted URLs. And I list the 10 correct URLs (There are 10,000 correct URLs in total).

# %%
df_merge = df_merge.dropna()

# %%
def string_similar(s1, s2):
    return difflib.SequenceMatcher(None, s1, s2).quick_ratio()

# %%
for i in range(df_corrupted['product'].isnull().sum()):
    for j in range(50):
        if string_similar(urllib.parse.quote(df_corrupted.iloc[i,2]),urllib.parse.quote(df_product.iloc[j,1]))>0.94:
            df_corrupted.iloc[i,2] = df_product.iloc[j,1]

# %%
x=df_corrupted.iloc[:,0:6]
df_merge1 = pd.merge(x, df_product, on="Product URL", how="left",validate='many_to_one')
df_real = pd.concat([df_merge, df_merge1])
df_real.head(10)
# Out:
#   Sentiment                  Publication_URL                     Product URL  \
# 0  positive         https://www.foxnews.com/          https://lees.com/jeans
# 1   neutral   https://www.mirror.co.uk/news/        https://coach.com/purses
# 2  negative         https://www.nbcnews.com/  https://covergirl.co/lipsticks
# 3  positive        https://www.examiner.com/     https://covergirl.co/makeup
# 4  negative               https://www.nj.com      https://dell.com/computers
# 5  positive  https://www.chicagotribune.com/   https://remington.com/shavers
# 6  negative   https://www.msn.com/en-us/news        https://dell.com/laptops
# 7  positive           https://www.salon.com/     https://samsung.com/washers
# 8  positive            https://www.cnet.com/          https://Ikea.com/sofas
# 9  negative        https://www.buzzfeed.com/  https://InstantPot.com/cookers
#
#    clickORnot  gender   age_group                     product     product_type
# 0           0  female    juvenile                   Lee jeans            jeans
# 1           0    male       young                 Coach purse    women's purse
# 2           0    male  middle-age          covergirl lipstick         lipstick
# 3           0    male    juvenile            Covergirl makeup           makeup
# 4           1  female       young               Dell computer         computer
# 5           1    male      senior            Remington shaver           shaver
# 6           0    male       young                 Dell laptop         computer
# 7           1    male    juvenile              Samsung washer           washer
# 8           0    male      senior                   Ikea sofa        furniture
# 9           0  female      senior  InstantPot pressure cooker  pressure cooker

# %% [markdown]
# # <center> Task 3

# %% [markdown]
# For each product, compute all the Publication_URLs containing an ad for that product. (Don’t just give the results. Show all the work by which you got those results. This applies to all the questions below.) (10)

# %% [markdown]
# # <center> Answer

# %% [markdown]
# - Once we have the correct dataframe without missing value, the computation of subsequent tasks is feasible. For Task 3, groupby.sum() function in Pandas package could compute and list all the Publication_URLs containing an ad for that product. (groupby 'product' and 'Publication_URL').

# %%
warnings.filterwarnings("ignore")
df_product.sort_values("product",inplace=True,ignore_index = True)
pro = df_product["product"].drop_duplicates().reset_index(drop=True)
df_real_q3 = df_real.iloc[:,[6,1]]
df_real_q3.sort_values("product",inplace=True,ignore_index =True)
df_q3 = pd.DataFrame(columns=['product','Publication_URL'])
for i in range(50):
    df = df_real_q3[df_real_q3['product'] == pro[i]]
    y = ""
    for j in range(df.shape[0]):
        y += df_real_q3.iloc[j,1]
        y +=","
    df_q3= df_q3.append(pd.DataFrame({'product':[pro[i]],'Publication_URL':[y]}),ignore_index = True)
df_q3
# Out:
#                        product  \
# 0               Apple computer
# 1                   Apple iPad
# 2                 Apple laptop
# 3           BasilBasel perfume
# 4            Broyhill recliner
# 5        Centrum MultiVitamins
# 6         Clinique moisturizer
# 7                  Coach purse
# 8                 Cougar jeans
# 9             Covergirl makeup
# 10               Dell computer
# 11                 Dell laptop
# 12                Docker pants
# 13                 Ford  sedan
# 14             Gillette shaver
# 15             Giorgio perfume
# 16            Givenchy perfume
# 17               Guess perfume
# 18          Haier refrigerator
# 19      Hamilton Beach blender
# 20                   Ikea sofa
# 21  InstantPot pressure cooker
# 22              Jaguar perfume
# 23               Kaai handbags
# 24                       LG TV
# 25                    LG dryer
# 26                   LG washer
# 27              Lavazza Coffee
# 28                   Lee jeans
# 29               Lenova laptop
# 30                 Levis Jeans
# 31         Maybelline lipstick
# 32                Maytag dryer
# 33         Maytag refrigerator
# 34               Maytag washer
# 35               NemoK blender
# 36      NordicTrack elliptical
# 37           NordicTrack rower
# 38       NordicTrack treadmill
# 39            Remington shaver
# 40                  Samsung TV
# 41               Samsung dryer
# 42              Samsung washer
# 43                     Sony TV
# 44          Soundwave speakers
# 45            Starbucks Coffee
# 46                       Tesla
# 47             Vitamix blender
# 48               bose speakers
# 49          covergirl lipstick
#
#                                       Publication_URL
# 0   https://www.mirror.co.uk/news/,https://www.bos...
# 1   https://www.mirror.co.uk/news/,https://www.bos...
# 2   https://www.mirror.co.uk/news/,https://www.bos...
# 3   https://www.mirror.co.uk/news/,https://www.bos...
# 4   https://www.mirror.co.uk/news/,https://www.bos...
# 5   https://www.mirror.co.uk/news/,https://www.bos...
# 6   https://www.mirror.co.uk/news/,https://www.bos...
# 7   https://www.mirror.co.uk/news/,https://www.bos...
# 8   https://www.mirror.co.uk/news/,https://www.bos...
# 9   https://www.mirror.co.uk/news/,https://www.bos...
# 10  https://www.mirror.co.uk/news/,https://www.bos...
# 11  https://www.mirror.co.uk/news/,https://www.bos...
# 12  https://www.mirror.co.uk/news/,https://www.bos...
# 13  https://www.mirror.co.uk/news/,https://www.bos...
# 14  https://www.mirror.co.uk/news/,https://www.bos...
# 15  https://www.mirror.co.uk/news/,https://www.bos...
# 16  https://www.mirror.co.uk/news/,https://www.bos...
# 17  https://www.mirror.co.uk/news/,https://www.bos...
# 18  https://www.mirror.co.uk/news/,https://www.bos...
# 19  https://www.mirror.co.uk/news/,https://www.bos...
# 20  https://www.mirror.co.uk/news/,https://www.bos...
# 21  https://www.mirror.co.uk/news/,https://www.bos...
# 22  https://www.mirror.co.uk/news/,https://www.bos...
# 23  https://www.mirror.co.uk/news/,https://www.bos...
# 24  https://www.mirror.co.uk/news/,https://www.bos...
# 25  https://www.mirror.co.uk/news/,https://www.bos...
# 26  https://www.mirror.co.uk/news/,https://www.bos...
# 27  https://www.mirror.co.uk/news/,https://www.bos...
# 28  https://www.mirror.co.uk/news/,https://www.bos...
# 29  https://www.mirror.co.uk/news/,https://www.bos...
# 30  https://www.mirror.co.uk/news/,https://www.bos...
# 31  https://www.mirror.co.uk/news/,https://www.bos...
# 32  https://www.mirror.co.uk/news/,https://www.bos...
# 33  https://www.mirror.co.uk/news/,https://www.bos...
# 34  https://www.mirror.co.uk/news/,https://www.bos...
# 35  https://www.mirror.co.uk/news/,https://www.bos...
# 36  https://www.mirror.co.uk/news/,https://www.bos...
# 37  https://www.mirror.co.uk/news/,https://www.bos...
# 38  https://www.mirror.co.uk/news/,https://www.bos...
# 39  https://www.mirror.co.uk/news/,https://www.bos...
# 40  https://www.mirror.co.uk/news/,https://www.bos...
# 41  https://www.mirror.co.uk/news/,https://www.bos...
# 42  https://www.mirror.co.uk/news/,https://www.bos...
# 43  https://www.mirror.co.uk/news/,https://www.bos...
# 44  https://www.mirror.co.uk/news/,https://www.bos...
# 45  https://www.mirror.co.uk/news/,https://www.bos...
# 46  https://www.mirror.co.uk/news/,https://www.bos...
# 47  https://www.mirror.co.uk/news/,https://www.bos...
# 48  https://www.mirror.co.uk/news/,https://www.bos...
# 49  https://www.mirror.co.uk/news/,https://www.bos...

# %% [markdown]
# # <center> Task 4

# %% [markdown]
# For each product type, compute all the Publication_URLs containing an ad for that product type. Your solution must be scalable. That is, it should work well even if there are hundreds of products in each product_type and there are hundreds of product_types. (Hint: To make it scalable you should consider using a Python or PySpark script instead of a SQL query.) (20)

# %% [markdown]
# # <center> Answer

# %% [markdown]
# - For Task 4, groupby.sum() function in Pandas package could compute and list all the Publication_URLs containing an ad for that product type. (groupby 'product_type' and 'Publication_URL'). And this solution is scalable. It should work well even if there are hundreds of products in each product_type and there are hundreds of product_types.

# %%
warnings.filterwarnings("ignore")
df_product.sort_values("product_type",inplace=True,ignore_index = True)
x = df_product["product_type"].drop_duplicates().reset_index(drop=True)
df_real_q4 = df_real.iloc[:,[7,1]]
df_real_q4.sort_values("product_type",inplace=True,ignore_index =True)
df_q5 = pd.DataFrame(columns=['product_type','Publication_URL'])
for i in range(24):
    df = df_real_q4[df_real_q4['product_type'] == x[i]]
    y = ""
    for j in range(df.shape[0]):
        y += df_real_q4.iloc[j,1]
        y +=","
    df_q5= df_q5.append(pd.DataFrame({'product_type':[x[i]],'Publication_URL':[y]}),ignore_index = True)
df_q5
# Out:
#           product_type                                    Publication_URL
# 0              blender  https://techcrunch.com/,https://www.npr.org/,h...
# 1                  car  https://techcrunch.com/,https://www.npr.org/,h...
# 2               coffee  https://techcrunch.com/,https://www.npr.org/,h...
# 3             computer  https://techcrunch.com/,https://www.npr.org/,h...
# 4                dryer  https://techcrunch.com/,https://www.npr.org/,h...
# 5   elliptical trainer  https://techcrunch.com/,https://www.npr.org/,h...
# 6           face cream  https://techcrunch.com/,https://www.npr.org/,h...
# 7            furniture  https://techcrunch.com/,https://www.npr.org/,h...
# 8                jeans  https://techcrunch.com/,https://www.npr.org/,h...
# 9             lipstick  https://techcrunch.com/,https://www.npr.org/,h...
# 10              makeup  https://techcrunch.com/,https://www.npr.org/,h...
# 11               pants  https://techcrunch.com/,https://www.npr.org/,h...
# 12             perfume  https://techcrunch.com/,https://www.npr.org/,h...
# 13     pressure cooker  https://techcrunch.com/,https://www.npr.org/,h...
# 14        refrigerator  https://techcrunch.com/,https://www.npr.org/,h...
# 15      rowing machine  https://techcrunch.com/,https://www.npr.org/,h...
# 16              shaver  https://techcrunch.com/,https://www.npr.org/,h...
# 17            speakers  https://techcrunch.com/,https://www.npr.org/,h...
# 18              tablet  https://techcrunch.com/,https://www.npr.org/,h...
# 19          television  https://techcrunch.com/,https://www.npr.org/,h...
# 20           treadmill  https://techcrunch.com/,https://www.npr.org/,h...
# 21             vitamin  https://techcrunch.com/,https://www.npr.org/,h...
# 22              washer  https://techcrunch.com/,https://www.npr.org/,h...
# 23       women's purse  https://techcrunch.com/,https://www.npr.org/,h...

# %% [markdown]
# # <center> Task 5

# %% [markdown]
# Save this information in the database. Should you save it in the products table or the product_categories table or should you create a new table, product_type_pubURLs, and save this information in this table? If you create a new table, make sure to set up all the appropriate foreign key constraints. On the other hand, if you use one of the existing tables, explain how you will avoid redundancy in your data. In either case, justify your decision. (10)

# %% [markdown]
# # <center> Answer

# %% [markdown]
# - For task 5, I choose to create create a new table product_type_pubURLs. This new table has two attributes: "product_type" and "Publication_URL". And I merge the result into the following form and store it this way in sql:
#     - "type_a" "[url1, url2, url3, url4, ...]"
# - And I set up the appropriate foreign key constraints (foreign key: product_type_pubURLs (product_type) to product_categories (product_type))

# %%
import os
import mysql.connector

# %%
db = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="001011",
    database="data1050"   
)
print(db)
if db.is_connected():
    print("CONNECTION SUCCESSFUL")
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x000001FC09B7BA90>
# CONNECTION SUCCESSFUL

# %%
mycursor = db.cursor()
mycursor.execute("DROP TABLE IF EXISTS `product_type_sentiment_clickrate`")
mycursor.execute("DROP TABLE IF EXISTS `product_type_pubURLs`")
mycursor.execute("DROP TABLE IF EXISTS `product_categories`")

# %%
#df_prodect_category
df_prodect_category = pd.read_csv('product_categories.csv')
df_prodect_category.sort_values("product_type",inplace=True,ignore_index = True)
df_prodect_category=df_prodect_category.drop(labels=17)
mycursor.execute(
"""
CREATE TABLE product_categories (
product_type varchar(255) PRIMARY KEY,
category varchar(255)
)
"""
)
mycursor.execute("DESCRIBE product_categories")
for x in mycursor:
    print(x)
# Out:
# ('product_type', b'varchar(255)', 'NO', 'PRI', None, '')
# ('category', b'varchar(255)', 'YES', '', None, '')

# %%
for i in range(24):
    product_type = df_prodect_category.iloc[i,0]
    category = df_prodect_category.iloc[i,1]
    insert_val = tuple((product_type,category))
    mycursor.execute("INSERT INTO product_categories(product_type,category) VALUES (%s, %s)", insert_val)
mycursor.execute("select * from product_categories")
mycursor.fetchall()
# Out:
# [('blender', 'small kitchen appliances'),
#  ('car', 'transportation'),
#  ('coffee', 'packaged food'),
#  ('computer', 'consumer electronics'),
#  ('dryer', 'large kitchen appliances'),
#  ('elliptical trainer', 'fitness equipment'),
#  ('face cream', 'beauty products'),
#  ('furniture', 'household durables'),
#  ('jeans', 'apparel'),
#  ('lipstick', 'beauty products'),
#  ('makeup', 'beauty products'),
#  ('pants', 'apparel'),
#  ('perfume', 'beauty products'),
#  ('pressure cooker', 'small kitchen appliances'),
#  ('refrigerator', 'large kitchen appliances'),
#  ('rowing machine', 'fitness equipment'),
#  ('shaver', 'consumer electronics'),
#  ('speakers', 'consumer electronics'),
#  ('tablet', 'consumer electronics'),
#  ('television', 'consumer electronics'),
#  ('treadmill', 'fitness equipment'),
#  ('vitamin', 'health'),
#  ('washer', 'large kitchen appliances'),
#  ("women's purse", 'accessories')]

# %%
mycursor.execute(
"""
CREATE TABLE product_type_pubURLs (
product_type varchar(255) PRIMARY KEY,
Publication_URL text,
FOREIGN KEY (product_type) REFERENCES product_categories(product_type)
)
"""
)
mycursor.execute("DESCRIBE product_type_pubURLs")
for x in mycursor:
    print(x)
# Out:
# ('product_type', b'varchar(255)', 'NO', 'PRI', None, '')
# ('Publication_URL', b'text', 'YES', '', None, '')

# %%
df_product.sort_values("product_type",inplace=True,ignore_index = True)
x = df_product["product_type"].drop_duplicates().reset_index(drop=True)

# %%
warnings.filterwarnings("ignore")
for i in range(24):
    product_type = df_q5.iloc[i,0]
    Publication_URL = df_q5.iloc[i,1]
    insert_val = tuple((product_type,Publication_URL))
    mycursor.execute("INSERT INTO product_type_pubURLs(product_type,Publication_URL) VALUES (%s, %s)", insert_val)

# %%
mycursor = db.cursor()
mycursor.execute("select * from product_type_pubURLs LIMIT 0,1")
mycursor.fetchall()
# Out:
# [('blender',
#   'https://techcrunch.com/,https://www.npr.org/,https://www.usatoday.com/,https://www.vox.com/,https://www.boston.com,https://www.foxnews.com/,https://www.bostonglobe.com/,https://www.examiner.com/,https://mashable.com/,https://www.theatlantic.com/,https://www.nydailynews.com/,https://www.independent.co.uk/,https://www.dallasnews.com/,https://www.sfgate.com/,https://abcnews.go.com/,https://time.com/,https://www.cbsnews.com/,https://www.vox.com/,https://www.sfgate.com/,https://www.huffingtonpost.com/,https://www.cbsnews.com/,https://www.usatoday.com/,https://www.examiner.com/,https://www.cnn.com/,https://www.foxnews.com/,https://www.foxnews.com/,https://nypost.com/,https://www.al.com/,https://www.upworthy.com/,https://www.businessinsider.com/,https://www.nbcnews.com/,https://www.nbcnews.com/,https://nypost.com/,https://www.dailymail.co.uk/,https://mashable.com/,https://www.vox.com/,https://time.com/,https://www.npr.org/,https://www.dallasnews.com/,https://www.usnews.com/,https://www.dallasnews.com/,https://www.sfgate.com/,https://www.dallasnews.com/,https://www.examiner.com/,https://www.nydailynews.com/,https://www.independent.co.uk/,https://www.cnn.com/,https://www.businessinsider.com/,https://www.nbcnews.com/,https://www.nydailynews.com/,https://www.latimes.com/,https://mashable.com/,https://www.dailymail.co.uk/,https://www.usatoday.com/,https://time.com/,https://abcnews.go.com/,https://www.sfgate.com/,https://www.foxnews.com/,https://abcnews.go.com/,https://www.cnn.com/,https://www.usatoday.com/,https://abcnews.go.com/,https://www.latimes.com/,https://www.npr.org/,https://www.cnn.com/,https://www.huffingtonpost.com/,https://www.latimes.com/,https://www.bostonglobe.com/,https://www.salon.com/,https://www.salon.com/,https://www.boston.com,https://www.theatlantic.com/,https://www.cbsnews.com/,https://www.nytimes.com/,https://www.vox.com/,https://www.foxnews.com/,https://www.dailymail.co.uk/,https://www.nydailynews.com/,https://www.dallasnews.com/,https://abcnews.go.com/,https://time.com/,https://www.boston.com,https://time.com/,https://www.vox.com/,https://www.foxnews.com/,https://abcnews.go.com/,https://www.usnews.com/,https://www.independent.co.uk/,https://www.usatoday.com/,https://abcnews.go.com/,https://www.dallasnews.com/,https://www.usnews.com/,https://www.foxnews.com/,https://www.usnews.com/,https://www.bostonglobe.com/,https://www.nytimes.com/,https://www.dallasnews.com/,https://www.salon.com/,https://www.bostonglobe.com/,https://www.nbcnews.com/,https://www.cbsnews.com/,https://www.bostonglobe.com/,https://www.sfgate.com/,https://www.dallasnews.com/,https://www.nj.com,https://techcrunch.com/,https://www.sfgate.com/,https://www.usnews.com/,https://www.nj.com,https://www.theguardian.com/us,https://www.cbsnews.com/,https://mashable.com/,https://www.bostonglobe.com/,https://www.salon.com/,https://nypost.com/,https://www.cbsnews.com/,https://time.com/,https://www.independent.co.uk/,https://www.bostonglobe.com/,https://www.al.com/,https://www.vox.com/,https://abcnews.go.com/,https://techcrunch.com/,https://www.foxnews.com/,https://www.theatlantic.com/,https://techcrunch.com/,https://nypost.com/,https://www.cnn.com/,https://www.nbcnews.com/,https://www.vox.com/,https://www.bostonglobe.com/,https://time.com/,https://www.usatoday.com/,https://mashable.com/,https://www.vox.com/,https://www.npr.org/,https://www.foxnews.com/,https://www.vox.com/,https://www.usatoday.com/,https://www.boston.com,https://www.sfgate.com/,https://www.cbsnews.com/,https://mashable.com/,https://www.foxnews.com/,https://www.huffingtonpost.com/,https://mashable.com/,https://www.usnews.com/,https://www.salon.com/,https://nypost.com/,https://www.nytimes.com/,https://www.usatoday.com/,https://www.usnews.com/,https://www.nydailynews.com/,https://www.al.com/,https://www.usnews.com/,https://www.salon.com/,https://www.theguardian.com/us,https://www.usatoday.com/,https://www.foxnews.com/,https://www.sfgate.com/,https://www.npr.org/,https://www.theatlantic.com/,htt ...

# %%
db.close()
mycursor.close()
# Out:
# True

# %% [markdown]
# # <center> Task 6

# %% [markdown]
# For each product, compute the click rate for it. (Click rate is the number of times a display of an ad was clicked on (by any user) divided by the number of times it was displayed (to any user). That is, the click rate is not specific to each user.)

# %% [markdown]
# # <center> Answer

# %% [markdown]
# - For Task 6, groupby.apply(lambda x: x.sum()/len(x)) function in Pandas package could compute and list all the click rate for each product. (groupby 'product'). And this solution is scalable. It should work well even if there are hundreds of products in each product_type and there are hundreds of product_types.

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
import numpy as np
df_prod = df_real[["product"]]
df_click = df_real[["clickORnot"]]

# %%
onehot_ftrs = ['product']
preprocessor = ColumnTransformer(
transformers=[('onehot', OneHotEncoder(sparse=False, handle_unknown='ignore'),onehot_ftrs)])
clf = Pipeline(steps=[('preprocessor', preprocessor)])
df_prod = clf.fit_transform(df_prod)
df_train = pd.DataFrame(df_prod, columns=preprocessor.get_feature_names_out())[:len(df_prod)]
df_prod_click = pd.concat([df_train,pd.DataFrame(np.reshape(np.array(df_click), (1, -1)).ravel(),columns=['clickORnot'])],axis=1)

# %%
click_rate = np.zeros(50)
df_product.sort_values("product",inplace=True,ignore_index = True)
for i in range(50):
    click_rate[i] = df_prod_click.loc[df_prod_click[df_prod_click.columns.values[i]] == 1]['clickORnot'].sum()/df_prod_click.loc[df_prod_click[df_prod_click.columns.values[i]] == 1][df_prod_click.columns.values[i]].sum()
    #print('The Click rate for', df_product['product'][i],'is', click_rate[i])

# %%
df_log_products_on_product_URL_6 = df_real[['product', 'clickORnot']]
df_log_products_on_product_URL_6.groupby(['product']).apply(lambda x: x.sum()/len(x))
# Out:
#                             clickORnot
# product
# Apple computer                0.793103
# Apple iPad                    0.503788
# Apple laptop                  0.560976
# BasilBasel perfume            0.649351
# Broyhill recliner             0.539216
# Centrum MultiVitamins         0.626556
# Clinique moisturizer          0.805556
# Coach purse                   0.388646
# Cougar jeans                  0.260073
# Covergirl makeup              0.252475
# Dell computer                 0.651584
# Dell laptop                   0.315186
# Docker pants                  0.685897
# Ford  sedan                   0.136564
# Gillette shaver               0.713376
# Giorgio perfume               0.799065
# Givenchy perfume              0.459716
# Guess perfume                 0.406977
# Haier refrigerator            0.207547
# Hamilton Beach blender        0.407767
# Ikea sofa                     0.573034
# InstantPot pressure cooker    0.500000
# Jaguar perfume                0.473282
# Kaai handbags                 0.660000
# LG TV                         0.480769
# LG dryer                      0.630435
# LG washer                     0.495327
# Lavazza Coffee                0.564103
# Lee jeans                     0.466981
# Lenova laptop                 0.639024
# Levis Jeans                   0.668142
# Maybelline lipstick           0.560976
# Maytag dryer                  0.344828
# Maytag refrigerator           0.396552
# Maytag washer                 0.506944
# NemoK blender                 0.569672
# NordicTrack elliptical        0.528409
# NordicTrack rower             0.223404
# NordicTrack treadmill         0.489712
# Remington shaver              0.349650
# Samsung TV                    0.731250
# Samsung dryer                 0.435897
# Samsung washer                0.550943
# Sony TV                       0.392857
# Soundwave speakers            0.545894
# Starbucks Coffee              0.275974
# Tesla                         0.591667
# Vitamix blender               0.507317
# bose speakers                 0.525510
# covergirl lipstick            0.820144

# %% [markdown]
# # <center> Task 7

# %% [markdown]
# For each product, compute the click rate for each sentiment type. (10)

# %% [markdown]
# # <center> Answer

# %% [markdown]
# - For each product, groupby.apply(lambda x: x.sum()/len(x)) function in Pandas package could compute and list all the click rate for each sentiment type. (groupby 'product','Sentiment'). And this solution is scalable. It should work well even if there are hundreds of products in each product_type and there are hundreds of product_types.

# %%
df_senti = df_real[["Sentiment"]]
df_senti = df_senti.reset_index(drop=True)
df_prod_click = df_prod_click.reset_index(drop=True)

# %%
df_prod_click_sentiment = pd.concat([df_prod_click,df_senti],axis=1)

# %%
positive = df_prod_click_sentiment[df_prod_click_sentiment['Sentiment']== 'positive'] 
neutral = df_prod_click_sentiment[df_prod_click_sentiment['Sentiment']== 'neutral'] 
negative = df_prod_click_sentiment[df_prod_click_sentiment['Sentiment']== 'negative']

# %%
click_rate_positive = np.zeros(50)
click_rate_neutral = np.zeros(50)
click_rate_negative = np.zeros(50)
df_product.sort_values("product",inplace=True,ignore_index = True)
for i in range(50):
    click_rate_positive[i] = positive.loc[positive[positive.columns.values[i]] == 1]['clickORnot'].sum()/positive.loc[positive[positive.columns.values[i]] == 1][positive.columns.values[i]].sum()
    click_rate_neutral[i] = neutral.loc[neutral[neutral.columns.values[i]] == 1]['clickORnot'].sum()/neutral.loc[neutral[neutral.columns.values[i]] == 1][neutral.columns.values[i]].sum()
    click_rate_negative[i] = negative.loc[negative[negative.columns.values[i]] == 1]['clickORnot'].sum()/negative.loc[negative[negative.columns.values[i]] == 1][negative.columns.values[i]].sum()
    #print('The Click rate for', df_product['product'][i],'(Sentiment is positive)','is', click_rate_positive[i])
    #print('The Click rate for', df_product['product'][i],'(Sentiment is neutral)','is', click_rate_neutral[i])
    #print('The Click rate for', df_product['product'][i],'(Sentiment is negative)','is', click_rate_negative[i])

# %%
pd.set_option('display.max_rows', 1000)
df_log_products_on_product_URL_7 = df_real[['product', 'Sentiment', 'clickORnot']]
df_log_products_on_product_URL_7.groupby(['product', 'Sentiment']).apply(lambda x: x.sum()/len(x))
# Out:
#                                       clickORnot
# product                    Sentiment
# Apple computer             negative     0.700000
#                            neutral      0.923077
#                            positive     0.764706
# Apple iPad                 negative     0.391304
#                            neutral      0.627907
#                            positive     0.500000
# Apple laptop               negative     0.153846
#                            neutral      0.725000
#                            positive     0.772727
# BasilBasel perfume         negative     0.771429
#                            neutral      0.864407
#                            positive     0.366667
# Broyhill recliner          negative     0.814286
#                            neutral      0.562500
#                            positive     0.242857
# Centrum MultiVitamins      negative     0.835294
#                            neutral      0.814815
#                            positive     0.186667
# Clinique moisturizer       negative     0.902778
#                            neutral      0.930556
#                            positive     0.583333
# Coach purse                negative     0.316456
#                            neutral      0.453333
#                            positive     0.400000
# Cougar jeans               negative     0.083333
#                            neutral      0.311688
#                            positive     0.390000
# Covergirl makeup           negative     0.112676
#                            neutral      0.384615
#                            positive     0.245283
# Dell computer              negative     0.830986
#                            neutral      0.382353
#                            positive     0.719512
# Dell laptop                negative     0.145299
#                            neutral      0.357143
#                            positive     0.452830
# Docker pants               negative     0.835821
#                            neutral      0.818182
#                            positive     0.333333
# Ford  sedan                negative     0.013158
#                            neutral      0.125000
#                            positive     0.265823
# Gillette shaver            negative     0.904762
#                            neutral      0.960784
#                            positive     0.139535
# Giorgio perfume            negative     0.638554
#                            neutral      0.969697
#                            positive     0.830769
# Givenchy perfume           negative     0.757576
#                            neutral      0.302632
#                            positive     0.347826
# Guess perfume              negative     0.172414
#                            neutral      0.306452
#                            positive     0.788462
# Haier refrigerator         negative     0.173077
#                            neutral      0.166667
#                            positive     0.283019
# Hamilton Beach blender     negative     0.671642
#                            neutral      0.353846
#                            positive     0.216216
# Ikea sofa                  negative     0.840000
#                            neutral      0.594203
#                            positive     0.322034
# InstantPot pressure cooker negative     0.000000
#                            neutral      0.864407
#                            positive     0.714286
# Jaguar perfume             negative     0.434783
#                            neutral      0.700000
#                            positive     0.311111
# Kaai handbags              negative     0.490566
#                            neutral      0.956522
#                            positive     0.512821
# LG TV                      negative     0.298507
#                            neutral      0.590909
#                            positive     0.644444
# LG dryer                   negative     0.680851
#                            neutral      0.791667
#                            positive     0.395349
# LG washer                  negative     0.153846
#                            neutral      0.516667
#                            positive     0.828947
# Lavazza Coffee             negative     0.840909
#                            neutral      0.447368
#                            positive     0.342857
# Lee jeans                  negative     0.342466
#                            neutral      0.777778
#                            positive     0.328947
# Lenova laptop              negative     0.750000
#                            neutral      0.718310
#                            positive     0.419355
# Levis Jeans                negative     0.404762
#                            neutral      0.800000
#                            positive     0.844156
# Maybelline lipstick        negative     0.885246
#                            neutral      0.209877
#                            positive     0.698413
# Maytag dryer               negative     0.117647
#                            neutral      0.704918
#                            positive     0.256757
# Maytag refrigerator        negative     0.052632
#                            neutral      0.722222
#                            positive     0.428571
# Maytag washer              negative     0.922222
#                            neutral      0.361702
#                            positive     0.278846
# NemoK blender              negative     0.978261
#                            neutral      0.325843
#                            positive     0.317460
# NordicTrack elliptical     negative     0.491228
#                            neutral      0.737705
#                            positive     0.344828
# NordicTrack rower          negative     0.200000
#                            neutral      0.142857
#                            positive     0.297297
# NordicTrack treadmill      negative     0.316456
#                            neutral      0.584270
#                            positive     0.560000
# Remington shaver           negative     0.145161
#                            neutral      0.236842
#                            positive     0.744186
# Samsung TV                 negative     0.666667
#                            neutral      0.823529
#                            positive     0.703125
# Samsung dryer              negative     0.275862
#                            neutral      0.716981
#                            positive     0.311111
# Samsung washer             negative     0.000000
#                            neutral      0.698795
#                            positive     0.897959
# Sony TV                    negative     0.055556
#                            neutral      0.678571
#                            positive     0.431034
# Soundwave speakers         negative     0.119403
#                            neutral      0.955224
#                            positive     0.561644
# Starbucks Coffee           negative     0.300000
#                            neutral      0.323529
#                            positive     0.207547
# Tesla                      negative     0.791667
#                            neutral      0.987654
#                            positive     0.057471
# Vitamix blender            negative     0.536585
#                            neutral      0.338710
#                            positive     0.639344
# bose speakers              negative     0.596774
#                            neutral      0.463768
#                            positive     0.523077
# covergirl lipstick         negative     0.418605
#                            neutral      1.000000
#                            positive     1.000000

# %% [markdown]
# # <center> Task8

# %% [markdown]
# For each product type, compute the click rate for it. (10)

# %% [markdown]
# # <center> Answer

# %% [markdown]
# - For Task 8, groupby.apply(lambda x: x.sum()/len(x)) function in Pandas package could compute and list all the click rate for each product type. (groupby 'product'). And this solution is scalable. It should work well even if there are hundreds of products in each product_type and there are hundreds of product_types.

# %%
df_prod_type = df_real[["product_type"]]
df_click = df_real[["clickORnot"]]

# %%
onehot_ftrs = ['product_type']
preprocessor = ColumnTransformer(
transformers=[('onehot', OneHotEncoder(sparse=False, handle_unknown='ignore'),onehot_ftrs)])
clf = Pipeline(steps=[('preprocessor', preprocessor)])
df_prod_type = clf.fit_transform(df_prod_type)
df_train = pd.DataFrame(df_prod_type, columns=preprocessor.get_feature_names_out())[:len(df_prod_type)]
df_train = df_train.reset_index(drop=True)
df_click = df_click.reset_index(drop=True)
df_prod_type_click = pd.concat([df_train,df_click],axis=1)

# %%
click_rate = np.zeros(24)
df_product.sort_values("product_type",inplace=True,ignore_index = True)
x = df_product["product_type"].drop_duplicates().reset_index(drop=True)
for i in range(24):
    click_rate[i] = df_prod_type_click.loc[df_prod_type_click[df_prod_type_click.columns.values[i]] == 1]['clickORnot'].sum()/df_prod_type_click.loc[df_prod_type_click[df_prod_type_click.columns.values[i]] == 1][df_prod_type_click.columns.values[i]].sum()
    #print('The Click rate for', x[i],'is', click_rate[i])

# %%
df_log_products_on_product_URL_8 = df_real[['product_type', 'clickORnot']]
df_log_products_on_product_URL_8.groupby(['product_type']).apply(lambda x: x.sum()/len(x))
# Out:
#                     clickORnot
# product_type
# blender               0.499237
# car                   0.370450
# coffee                0.355294
# computer              0.558583
# dryer                 0.452716
# elliptical trainer    0.528409
# face cream            0.805556
# furniture             0.554974
# jeans                 0.451477
# lipstick              0.665698
# makeup                0.252475
# pants                 0.685897
# perfume               0.566893
# pressure cooker       0.500000
# refrigerator          0.287273
# rowing machine        0.223404
# shaver                0.540000
# speakers              0.535980
# tablet                0.503788
# television            0.533058
# treadmill             0.489712
# vitamin               0.626556
# washer                0.518905
# women's purse         0.515152

# %% [markdown]
# # <center> Task9

# %% [markdown]
# For each product type compute the click rate for each sentiment type. (10)

# %% [markdown]
# # <center> Answer

# %% [markdown]
# - For each product type, groupby.apply(lambda x: x.sum()/len(x)) function in Pandas package could compute and list all the click rate for each sentiment type. (groupby 'product_type','Sentiment'). And this solution is scalable. It should work well even if there are hundreds of products in each product_type and there are hundreds of product_types.

# %%
df_prod_type_click_sentiment = pd.concat([df_prod_type_click,df_senti],axis=1)

# %%
positive = df_prod_type_click_sentiment[df_prod_type_click_sentiment['Sentiment']== 'positive'] 
neutral = df_prod_type_click_sentiment[df_prod_type_click_sentiment['Sentiment']== 'neutral'] 
negative = df_prod_type_click_sentiment[df_prod_type_click_sentiment['Sentiment']== 'negative']

# %%
warnings.filterwarnings("ignore")
click_rate_positive = np.zeros(24)
click_rate_neutral = np.zeros(24)
click_rate_negative = np.zeros(24)

df_9_positive = pd.DataFrame(columns=['type','Sentiment', 'click rate'])
df_9_neutral = pd.DataFrame(columns=['type','Sentiment', 'click rate'])
df_9_negative = pd.DataFrame(columns=['type', 'Sentiment','click rate'])

for i in range(24):
    click_rate_positive[i] = positive.loc[positive[positive.columns.values[i]]== 1]['clickORnot'].sum()/positive.loc[positive[positive.columns.values[i]]== 1][positive.columns.values[i]].sum()
    click_rate_neutral[i] = neutral.loc[neutral[neutral.columns.values[i]] ==1]['clickORnot'].sum()/neutral.loc[neutral[neutral.columns.values[i]] ==1][neutral.columns.values[i]].sum()
    click_rate_negative[i] = negative.loc[negative[negative.columns.values[i]]== 1]['clickORnot'].sum()/negative.loc[negative[negative.columns.values[i]]== 1][negative.columns.values[i]].sum()
for i in range(24):
    df_9_positive = df_9_positive.append(pd.DataFrame({'type':[x[i]],'Sentiment':['positive'],'click rate':[click_rate_positive[i]]}),ignore_index = True)
    df_9_neutral= df_9_neutral.append(pd.DataFrame({'type':[x[i]],'Sentiment':['neutral'],'click rate':[click_rate_neutral[i]]}),ignore_index = True)
    df_9_negative= df_9_negative.append(pd.DataFrame({'type':[x[i]],'Sentiment':['negative'],'click rate':[click_rate_negative[i]]}),ignore_index = True)
df_9 = pd.concat([df_9_positive, df_9_neutral,df_9_negative])
df_9.sort_values("type",inplace=True,ignore_index = True)

# %%
df_10 = pd.DataFrame(columns=['type', 'negative_click_rate','neutral_click_rate','positive_click_rate'])
for i in range(24):
    df_10 = df_10.append(pd.DataFrame({'type':[x[i]],'negative_click_rate':[click_rate_negative[i]],'neutral_click_rate':[click_rate_neutral[i]],'positive_click_rate':[click_rate_positive[i]]}),ignore_index = True)
df_10
# Out:
#                   type  negative_click_rate  neutral_click_rate  \
# 0              blender             0.742739            0.337963
# 1                  car             0.391892            0.581699
# 2               coffee             0.465278            0.357143
# 3             computer             0.501355            0.570270
# 4                dryer             0.323699            0.734568
# 5   elliptical trainer             0.491228            0.737705
# 6           face cream             0.902778            0.930556
# 7            furniture             0.825000            0.578947
# 8                jeans             0.264822            0.609756
# 9             lipstick             0.692308            0.511450
# 10              makeup             0.112676            0.384615
# 11               pants             0.835821            0.818182
# 12             perfume             0.555556            0.610561
# 13     pressure cooker             0.000000            0.864407
# 14        refrigerator             0.122222            0.388889
# 15      rowing machine             0.200000            0.142857
# 16              shaver             0.528000            0.651685
# 17            speakers             0.348837            0.705882
# 18              tablet             0.391304            0.627907
# 19          television             0.319277            0.701987
# 20           treadmill             0.316456            0.584270
# 21             vitamin             0.835294            0.814815
# 22              washer             0.376984            0.518987
# 23       women's purse             0.386364            0.694444
#
#     positive_click_rate
# 0              0.378788
# 1              0.156627
# 2              0.241135
# 3              0.604972
# 4              0.308642
# 5              0.344828
# 6              0.583333
# 7              0.279070
# 8              0.509881
# 9              0.825688
# 10             0.245283
# 11             0.333333
# 12             0.532646
# 13             0.714286
# 14             0.347368
# 15             0.297297
# 16             0.441860
# 17             0.543478
# 18             0.500000
# 19             0.592814
# 20             0.560000
# 21             0.186667
# 22             0.647482
# 23             0.457516

# %% [markdown]
# # <center> Task 10

# %% [markdown]
# Save this information you computed in 9 above in a database table. Should you save it in the products table or the product_categories table or the product_type_pubURLs table, or should you create a new table product_type_sentiment_clickrate, and save this information in this table? If you create a new table, make sure to set up all the appropriate foreign key constraints. On the other hand, if you use one of the existing tables, explain how you will avoid redundancy in your data. In either case, justify your decision.  (10)

# %% [markdown]
# # <center> Answer

# %% [markdown]
# - For task 10, I choose to create create a new table product_type_sentiment_clickrate. This new table has four attributes: "product_type", "negative click rate", "neutral click rate" and "positive click rate". And I merge the result into the following form and store it this way in sql:
#     - "type_a" "negative click rate" "neutral click rate" "positive click rate"
# - And I set up the appropriate foreign key constraints (foreign key: product_type_sentiment_clickrate (product_type) to product_categories (product))

# %%
df_10 = pd.DataFrame(columns=['type', 'negative_click_rate','neutral_click_rate','positive_click_rate'])
for i in range(24):
    df_10 = df_10.append(pd.DataFrame({'type':[x[i]],'negative_click_rate':[click_rate_negative[i]],'neutral_click_rate':[click_rate_neutral[i]],'positive_click_rate':[click_rate_positive[i]]}),ignore_index = True)
df_10
# Out:
#                   type  negative_click_rate  neutral_click_rate  \
# 0              blender             0.742739            0.337963
# 1                  car             0.391892            0.581699
# 2               coffee             0.465278            0.357143
# 3             computer             0.501355            0.570270
# 4                dryer             0.323699            0.734568
# 5   elliptical trainer             0.491228            0.737705
# 6           face cream             0.902778            0.930556
# 7            furniture             0.825000            0.578947
# 8                jeans             0.264822            0.609756
# 9             lipstick             0.692308            0.511450
# 10              makeup             0.112676            0.384615
# 11               pants             0.835821            0.818182
# 12             perfume             0.555556            0.610561
# 13     pressure cooker             0.000000            0.864407
# 14        refrigerator             0.122222            0.388889
# 15      rowing machine             0.200000            0.142857
# 16              shaver             0.528000            0.651685
# 17            speakers             0.348837            0.705882
# 18              tablet             0.391304            0.627907
# 19          television             0.319277            0.701987
# 20           treadmill             0.316456            0.584270
# 21             vitamin             0.835294            0.814815
# 22              washer             0.376984            0.518987
# 23       women's purse             0.386364            0.694444
#
#     positive_click_rate
# 0              0.378788
# 1              0.156627
# 2              0.241135
# 3              0.604972
# 4              0.308642
# 5              0.344828
# 6              0.583333
# 7              0.279070
# 8              0.509881
# 9              0.825688
# 10             0.245283
# 11             0.333333
# 12             0.532646
# 13             0.714286
# 14             0.347368
# 15             0.297297
# 16             0.441860
# 17             0.543478
# 18             0.500000
# 19             0.592814
# 20             0.560000
# 21             0.186667
# 22             0.647482
# 23             0.457516

# %%
db = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="001011",
    database="data1050"   
)
print(db)
if db.is_connected():
    print("CONNECTION SUCCESSFUL")
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x000001FC0C9A4310>
# CONNECTION SUCCESSFUL

# %%
mycursor = db.cursor()
mycursor.execute("DROP TABLE IF EXISTS `product_type_sentiment_clickrate`")

mycursor.execute(
"""
CREATE TABLE product_type_sentiment_clickrate (
product_type varchar(255) PRIMARY KEY,
negative_click_rate FLOAT(4),
neutral_click_rate FLOAT(4),
positive_click_rate FLOAT(4),
FOREIGN KEY (product_type) REFERENCES product_categories(product_type)
)
"""
)
mycursor.execute("DESCRIBE product_type_sentiment_clickrate")
for x in mycursor:
    print(x)
# Out:
# ('product_type', b'varchar(255)', 'NO', 'PRI', None, '')
# ('negative_click_rate', b'float', 'YES', '', None, '')
# ('neutral_click_rate', b'float', 'YES', '', None, '')
# ('positive_click_rate', b'float', 'YES', '', None, '')

# %%
for i in range(24):
    product_type = df_10.iloc[i,0]
    negative_click_rate = df_10.iloc[i,1]
    neutral_click_rate = df_10.iloc[i,2]
    positive_click_rate = df_10.iloc[i,3]
    insert_val = tuple((product_type,negative_click_rate,neutral_click_rate,positive_click_rate))
    mycursor.execute("INSERT INTO product_type_sentiment_clickrate(product_type,negative_click_rate,neutral_click_rate,positive_click_rate) VALUES (%s, %s,%s, %s)", insert_val)

# %%
mycursor = db.cursor()
mycursor.execute("select * from product_type_sentiment_clickrate")
mycursor.fetchall()
# Out:
# [('blender', 0.742739, 0.337963, 0.378788),
#  ('car', 0.391892, 0.581699, 0.156627),
#  ('coffee', 0.465278, 0.357143, 0.241135),
#  ('computer', 0.501355, 0.57027, 0.604972),
#  ('dryer', 0.323699, 0.734568, 0.308642),
#  ('elliptical trainer', 0.491228, 0.737705, 0.344828),
#  ('face cream', 0.902778, 0.930556, 0.583333),
#  ('furniture', 0.825, 0.578947, 0.27907),
#  ('jeans', 0.264822, 0.609756, 0.509881),
#  ('lipstick', 0.692308, 0.51145, 0.825688),
#  ('makeup', 0.112676, 0.384615, 0.245283),
#  ('pants', 0.835821, 0.818182, 0.333333),
#  ('perfume', 0.555556, 0.610561, 0.532646),
#  ('pressure cooker', 0.0, 0.864407, 0.714286),
#  ('refrigerator', 0.122222, 0.388889, 0.347368),
#  ('rowing machine', 0.2, 0.142857, 0.297297),
#  ('shaver', 0.528, 0.651685, 0.44186),
#  ('speakers', 0.348837, 0.705882, 0.543478),
#  ('tablet', 0.391304, 0.627907, 0.5),
#  ('television', 0.319277, 0.701987, 0.592814),
#  ('treadmill', 0.316456, 0.58427, 0.56),
#  ('vitamin', 0.835294, 0.814815, 0.186667),
#  ('washer', 0.376984, 0.518987, 0.647482),
#  ("women's purse", 0.386364, 0.694444, 0.457516)]

# %%
db.close()
mycursor.close()
# Out:
# True

# %% [markdown]
# # <center> Task 11

# %% [markdown]
# Determine if the gender of the person viewing ads make a difference with regard to the click rate of ads shown in different sentiment context. That is, determine if there are any ‘significant’ differences in the correlation between the sentiment type of the ad context and clicking on the product type conditioned on gender. You can decide if any difference counts as ‘significant’. (This is not a yes or no question. Compute the different correlations.)  (10)

# %% [markdown]
# # <center> Answer

# %% [markdown]
# - How to decide if any difference counts as ‘significant'?
#     - For a specific product type and a specific sentiment type, we can claculate the click rate for each gender (eg. for blender and sentiment type is positive, we get click rate (male) = 0.380435 and click rate (female) = 0.377358),
#     - I define the "degree of difference" as:
# ## <center>degree of difference $= \frac{|clickrate\ (male)\ -\ clickrate\ (female)|}{clickrate\ (male)\ +\ clickrate\ (female)} $</center>
#     - if the "degree of difference" $> 0.05$, I define the difference between click rate (male) and click rate (female) as "significant" (eg. for blender and sentiment type is positive, we get click rate (male) = 0.380435 and click rate (female) = 0.377358,
#     <center>"degree of difference" $= \frac{|0.380435-0.377358|}{(0.380435+0.377358)} < 0.05$</center>, so its "not significant").
# - And I compute and list didifferent correlations.

# %%
df_gender = df_real[["gender"]]
df_gender = df_gender.reset_index(drop=True)

# %%
df_male_positive = pd.DataFrame(columns=['type','Sentiment', 'click rate (male)'])
df_male_neutral = pd.DataFrame(columns=['type','Sentiment', 'click rate (male)'])
df_male_negative = pd.DataFrame(columns=['type', 'Sentiment','click rate (male)'])
df_prod_type_click_sentiment_gender = pd.concat([df_prod_type_click_sentiment,df_gender],axis=1)
x = df_product["product_type"].drop_duplicates().reset_index(drop=True)
df_diff_male =df_prod_type_click_sentiment_gender.loc[df_prod_type_click_sentiment_gender['gender'] == 'male']


positive = df_diff_male[df_diff_male['Sentiment']== 'positive'] 
neutral = df_diff_male[df_diff_male['Sentiment']== 'neutral'] 
negative = df_diff_male[df_diff_male['Sentiment']== 'negative'] 

warnings.simplefilter(action='ignore', category=FutureWarning)

click_rate_positive = np.zeros(24)
click_rate_neutral = np.zeros(24)
click_rate_negative = np.zeros(24)
for i in range(24):
    click_rate_positive[i] = positive.loc[positive[positive.columns.values[i]] == 1]['clickORnot'].sum()/positive.loc[positive[positive.columns.values[i]] == 1][positive.columns.values[i]].sum()
    click_rate_neutral[i] = neutral.loc[neutral[neutral.columns.values[i]] == 1]['clickORnot'].sum()/neutral.loc[neutral[neutral.columns.values[i]] == 1][neutral.columns.values[i]].sum()
    click_rate_negative[i] = negative.loc[negative[negative.columns.values[i]] == 1]['clickORnot'].sum()/negative.loc[negative[negative.columns.values[i]] == 1][negative.columns.values[i]].sum()
for i in range(24):
    df_male_positive = df_male_positive.append(pd.DataFrame({'type':[x[i]],'Sentiment':['positive'],'click rate (male)':[click_rate_positive[i]]}),ignore_index = True)
    df_male_neutral= df_male_neutral.append(pd.DataFrame({'type':[x[i]],'Sentiment':['neutral'],'click rate (male)':[click_rate_neutral[i]]}),ignore_index = True)
    df_male_negative= df_male_negative.append(pd.DataFrame({'type':[x[i]],'Sentiment':['negative'],'click rate (male)':[click_rate_negative[i]]}),ignore_index = True)
df_male = pd.concat([df_male_positive, df_male_neutral,df_male_negative])

# %%
df_female_positive = pd.DataFrame(columns=['type','Sentiment', 'click rate (female)'])
df_female_neutral = pd.DataFrame(columns=['type','Sentiment', 'click rate (female)'])
df_female_negative = pd.DataFrame(columns=['type', 'Sentiment','click rate (female)'])
df_prod_type_click_sentiment_gender = pd.concat([df_prod_type_click_sentiment,df_gender],axis=1)
df_diff_female =df_prod_type_click_sentiment_gender.loc[df_prod_type_click_sentiment_gender['gender'] == 'female']


positive = df_diff_female[df_diff_female['Sentiment']== 'positive'] 
neutral = df_diff_female[df_diff_female['Sentiment']== 'neutral'] 
negative = df_diff_female[df_diff_female['Sentiment']== 'negative'] 

warnings.simplefilter(action='ignore', category=FutureWarning)

click_rate_positive = np.zeros(24)
click_rate_neutral = np.zeros(24)
click_rate_negative = np.zeros(24)
for i in range(24):
    click_rate_positive[i] = positive.loc[positive[positive.columns.values[i]] == 1]['clickORnot'].sum()/positive.loc[positive[positive.columns.values[i]] == 1][positive.columns.values[i]].sum()
    click_rate_neutral[i] = neutral.loc[neutral[neutral.columns.values[i]] == 1]['clickORnot'].sum()/neutral.loc[neutral[neutral.columns.values[i]] == 1][neutral.columns.values[i]].sum()
    click_rate_negative[i] = negative.loc[negative[negative.columns.values[i]] == 1]['clickORnot'].sum()/negative.loc[negative[negative.columns.values[i]] == 1][negative.columns.values[i]].sum()
for i in range(24):
    df_female_positive = df_female_positive.append(pd.DataFrame({'type':[x[i]],'Sentiment':['positive'],'click rate (female)':[click_rate_positive[i]]}),ignore_index = True)
    df_female_neutral= df_female_neutral.append(pd.DataFrame({'type':[x[i]],'Sentiment':['neutral'],'click rate (female)':[click_rate_neutral[i]]}),ignore_index = True)
    df_female_negative= df_female_negative.append(pd.DataFrame({'type':[x[i]],'Sentiment':['negative'],'click rate (female)':[click_rate_negative[i]]}),ignore_index = True)
df_female = pd.concat([df_female_positive, df_female_neutral,df_female_negative])

# %%
df_merge_gender = pd.merge(df_male, df_female, on=['type','Sentiment'], how="left",validate='one_to_one')
df_gender_diff = pd.DataFrame(columns=['diff'])
for i in range(72):
    if abs(df_merge_gender.iloc[i,2] - df_merge_gender.iloc[i,3])/(df_merge_gender.iloc[i,2] + df_merge_gender.iloc[i,3]+0.00001) > 0.05:
        df_gender_diff = df_gender_diff.append(pd.DataFrame({'diff':['significant']}),ignore_index = True)
    else:
        df_gender_diff = df_gender_diff.append(pd.DataFrame({'diff':['not']}),ignore_index = True)
df_merge_gender_diff = pd.concat([df_merge_gender, df_gender_diff],axis = 1)
df_merge_gender_diff
# Out:
#                   type Sentiment  click rate (male)  click rate (female)  \
# 0              blender  positive           0.380435             0.377358
# 1                  car  positive           0.183908             0.126582
# 2               coffee  positive           0.217949             0.269841
# 3             computer  positive           0.614035             0.596859
# 4                dryer  positive           0.372093             0.236842
# 5   elliptical trainer  positive           0.424242             0.240000
# 6           face cream  positive           0.625000             0.550000
# 7            furniture  positive           0.298507             0.258065
# 8                jeans  positive           0.539130             0.485507
# 9             lipstick  positive           0.866667             0.775510
# 10              makeup  positive           0.205882             0.315789
# 11               pants  positive           0.238095             0.416667
# 12             perfume  positive           0.544218             0.520833
# 13     pressure cooker  positive           0.678571             0.742857
# 14        refrigerator  positive           0.250000             0.406780
# 15      rowing machine  positive           0.218750             0.357143
# 16              shaver  positive           0.518519             0.312500
# 17            speakers  positive           0.476190             0.600000
# 18              tablet  positive           0.428571             0.568182
# 19          television  positive           0.584416             0.600000
# 20           treadmill  positive           0.625000             0.485714
# 21             vitamin  positive           0.108108             0.263158
# 22              washer  positive           0.653846             0.641892
# 23       women's purse  positive           0.452055             0.462500
# 24             blender   neutral           0.291667             0.375000
# 25                 car   neutral           0.636364             0.526316
# 26              coffee   neutral           0.328358             0.383562
# 27            computer   neutral           0.584270             0.557292
# 28               dryer   neutral           0.730769             0.738095
# 29  elliptical trainer   neutral           0.758621             0.718750
# 30          face cream   neutral           0.944444             0.916667
# 31           furniture   neutral           0.515625             0.637681
# 32               jeans   neutral           0.596154             0.623762
# 33            lipstick   neutral           0.516129             0.507246
# 34              makeup   neutral           0.487805             0.270270
# 35               pants   neutral           0.800000             0.842105
# 36             perfume   neutral           0.574194             0.648649
# 37     pressure cooker   neutral           0.793103             0.933333
# 38        refrigerator   neutral           0.304348             0.477273
# 39      rowing machine   neutral           0.173913             0.115385
# 40              shaver   neutral           0.609756             0.687500
# 41            speakers   neutral           0.696970             0.714286
# 42              tablet   neutral           0.727273             0.566038
# 43          television   neutral           0.653333             0.750000
# 44           treadmill   neutral           0.590909             0.577778
# 45             vitamin   neutral           0.735294             0.872340
# 46              washer   neutral           0.528455             0.508772
# 47       women's purse   neutral           0.740741             0.634921
# 48             blender  negative           0.785714             0.695652
# 49                 car  negative           0.404762             0.375000
# 50              coffee  negative           0.435897             0.500000
# 51            computer  negative           0.500000             0.502618
# 52               dryer  negative           0.321839             0.325581
# 53  elliptical trainer  negative           0.535714             0.448276
# 54          face cream  negative           0.928571             0.886364
# 55           furniture  negative           0.800000             0.846154
# 56               jeans  negative           0.271930             0.258993
# 57            lipstick  negative           0.725490             0.660377
# 58              makeup  negative           0.103448             0.119048
# 59               pants  negative           0.810811             0.866667
# 60             perfume  negative           0.554795             0.556338
# 61     pressure cooker  negative           0.000000             0.000000
# 62        refrigerator  negative           0.026316             0.192308
# 63      rowing machine  negative           0.151515             0.250000
# 64              shaver  negative           0.461538             0.600000
# 65            speakers  negative           0.402778             0.280702
# 66              tablet  negative           0.377778             0.404255
# 67          television  negative           0.272727             0.371795
# 68           treadmill  negative           0.263158             0.365854
# 69             vitamin  negative           0.800000             0.875000
# 70              washer  negative           0.378788             0.375000
# 71       women's purse  negative           0.402985             0.369231
#
#            diff
# 0           not
# 1   significant
# 2   significant
# 3           not
# 4   significant
# 5   significant
# 6   significant
# 7   significant
# 8   significant
# 9   significant
# 10  significant
# 11  significant
# 12          not
# 13          not
# 14  significant
# 15  significant
# 16  significant
# 17  significant
# 18  significant
# 19          not
# 20  significant
# 21  significant
# 22          not
# 23          not
# 24  significant
# 25  significant
# 26  significant
# 27          not
# 28          not
# 29          not
# 30          not
# 31  significant
# 32          not
# 33          not
# 34  significant
# 35          not
# 36  significant
# 37  significant
# 38  significant
# 39  significant
# 40  significant
# 41          not
# 42  significant
# 43  significant
# 44          not
# 45  significant
# 46          not
# 47  significant
# 48  significant
# 49          not
# 50  significant
# 51          not
# 52          not
# 53  significant
# 54          not
# 55          not
# 56          not
# 57          not
# 58  significant
# 59          not
# 60          not
# 61          not
# 62  significant
# 63  significant
# 64  significant
# 65  significant
# 66          not
# 67  significant
# 68  significant
# 69          not
# 70          not
# 71          not

# %%
#y = df_merge_gender_diff.sort_values(by = ['type','Sentiment'],ignore_index = True)
#df_11 = df_real.iloc[:,[0,7]]
#x= df_11.groupby( ["product_type","Sentiment"]).count()
#x['result']=0
#for i in range(72):
#    x.iloc[i,0] = y['diff'][i]
#x

# %% [markdown]
# # <center> Task 12

# %% [markdown]
# The same question as 11 above but replace gender with age-group. (10)

# %% [markdown]
# - How to decide if any difference counts as ‘significant'?
#     - For a specific product type and a specific sentiment type, we can claculate the click rate for each age group
#     - I define the "degree of difference" as: $i = 1, 2, 3, 4$
# ## <center>degree of difference $= \frac{clickrate\ (age\ i)\ -\ average\ clickrate}{clickrate\ (age\ i)\ +\ average\ clickrate} $</center>
#     - if the "degree of difference" $> 0.05$, I define that this age group is significantly higher;
#     - if the "degree of difference" $< 0.05$, I define that this age group is significantly lower.
#     - If there’s an age group that is significantly higher than the average and an age group that is significantly lower, it would be reasonable to conclude that age is a significant factor for that product type and that sentiment.
# - And I compute and list didifferent correlations.
# - (PS: 'juvenile’, 'young’, 'middle-age’, 'senior' can be encoded as 1, 2, 3, 4 (1 being juvenile and so on). )

# %%
df_age = df_real[["age_group"]]
df_age = df_age.reset_index(drop=True)
df_product.sort_values("product_type",inplace=True,ignore_index = True)
x = df_product["product_type"].drop_duplicates().reset_index(drop=True)

# %%
df_juvenile_positive = pd.DataFrame(columns=['type','Sentiment', 'click rate1'])
df_juvenile_neutral = pd.DataFrame(columns=['type','Sentiment', 'click rate1'])
df_juvenile_negative = pd.DataFrame(columns=['type', 'Sentiment','click rate1'])
df_prod_type_click_sentiment_age = pd.concat([df_prod_type_click_sentiment,df_age],axis=1)
df_diff_juvenile =df_prod_type_click_sentiment_age.loc[df_prod_type_click_sentiment_age['age_group'] == 'juvenile']


positive = df_diff_juvenile[df_diff_juvenile['Sentiment']== 'positive'] 
neutral = df_diff_juvenile[df_diff_juvenile['Sentiment']== 'neutral'] 
negative = df_diff_juvenile[df_diff_juvenile['Sentiment']== 'negative'] 

warnings.simplefilter(action='ignore', category=FutureWarning)

click_rate_positive = np.zeros(24)
click_rate_neutral = np.zeros(24)
click_rate_negative = np.zeros(24)
for i in range(24):
    click_rate_positive[i] = positive.loc[positive[positive.columns.values[i]] == 1]['clickORnot'].sum()/positive.loc[positive[positive.columns.values[i]] == 1][positive.columns.values[i]].sum()
    click_rate_neutral[i] = neutral.loc[neutral[neutral.columns.values[i]] == 1]['clickORnot'].sum()/neutral.loc[neutral[neutral.columns.values[i]] == 1][neutral.columns.values[i]].sum()
    click_rate_negative[i] = negative.loc[negative[negative.columns.values[i]] == 1]['clickORnot'].sum()/negative.loc[negative[negative.columns.values[i]] == 1][negative.columns.values[i]].sum()
for i in range(24):
    df_juvenile_positive = df_juvenile_positive.append(pd.DataFrame({'type':[x[i]],'Sentiment':['positive'],'click rate1':[click_rate_positive[i]]}),ignore_index = True)
    df_juvenile_neutral= df_juvenile_neutral.append(pd.DataFrame({'type':[x[i]],'Sentiment':['neutral'],'click rate1':[click_rate_neutral[i]]}),ignore_index = True)
    df_juvenile_negative= df_juvenile_negative.append(pd.DataFrame({'type':[x[i]],'Sentiment':['negative'],'click rate1':[click_rate_negative[i]]}),ignore_index = True)
df_juvenile = pd.concat([df_juvenile_positive, df_juvenile_neutral,df_juvenile_negative])

# %%
df_young_positive = pd.DataFrame(columns=['type','Sentiment', 'click rate2'])
df_young_neutral = pd.DataFrame(columns=['type','Sentiment', 'click rate2'])
df_young_negative = pd.DataFrame(columns=['type', 'Sentiment','click rate2'])
df_prod_type_click_sentiment_age = pd.concat([df_prod_type_click_sentiment,df_age],axis=1)
df_diff_young =df_prod_type_click_sentiment_age.loc[df_prod_type_click_sentiment_age['age_group'] == 'young']


positive = df_diff_young[df_diff_young['Sentiment']== 'positive'] 
neutral = df_diff_young[df_diff_young['Sentiment']== 'neutral'] 
negative = df_diff_young[df_diff_young['Sentiment']== 'negative'] 

warnings.simplefilter(action='ignore', category=FutureWarning)

click_rate_positive = np.zeros(24)
click_rate_neutral = np.zeros(24)
click_rate_negative = np.zeros(24)
for i in range(24):
    click_rate_positive[i] = positive.loc[positive[positive.columns.values[i]] == 1]['clickORnot'].sum()/positive.loc[positive[positive.columns.values[i]] == 1][positive.columns.values[i]].sum()
    click_rate_neutral[i] = neutral.loc[neutral[neutral.columns.values[i]] == 1]['clickORnot'].sum()/neutral.loc[neutral[neutral.columns.values[i]] == 1][neutral.columns.values[i]].sum()
    click_rate_negative[i] = negative.loc[negative[negative.columns.values[i]] == 1]['clickORnot'].sum()/negative.loc[negative[negative.columns.values[i]] == 1][negative.columns.values[i]].sum()
for i in range(24):
    df_young_positive = df_young_positive.append(pd.DataFrame({'type':[x[i]],'Sentiment':['positive'],'click rate2':[click_rate_positive[i]]}),ignore_index = True)
    df_young_neutral= df_young_neutral.append(pd.DataFrame({'type':[x[i]],'Sentiment':['neutral'],'click rate2':[click_rate_neutral[i]]}),ignore_index = True)
    df_young_negative= df_young_negative.append(pd.DataFrame({'type':[x[i]],'Sentiment':['negative'],'click rate2':[click_rate_negative[i]]}),ignore_index = True)
df_young = pd.concat([df_young_positive, df_young_neutral,df_young_negative])

# %%
df_middleage_positive = pd.DataFrame(columns=['type','Sentiment', 'click rate3'])
df_middleage_neutral = pd.DataFrame(columns=['type','Sentiment', 'click rate3'])
df_middleage_negative = pd.DataFrame(columns=['type', 'Sentiment','click rate3'])
df_prod_type_click_sentiment_age = pd.concat([df_prod_type_click_sentiment,df_age],axis=1)
df_diff_middleage =df_prod_type_click_sentiment_age.loc[df_prod_type_click_sentiment_age['age_group'] == 'middle-age']


positive = df_diff_middleage[df_diff_middleage['Sentiment']== 'positive'] 
neutral = df_diff_middleage[df_diff_middleage['Sentiment']== 'neutral'] 
negative = df_diff_middleage[df_diff_middleage['Sentiment']== 'negative'] 

warnings.simplefilter(action='ignore', category=FutureWarning)

click_rate_positive = np.zeros(24)
click_rate_neutral = np.zeros(24)
click_rate_negative = np.zeros(24)
for i in range(24):
    click_rate_positive[i] = positive.loc[positive[positive.columns.values[i]] == 1]['clickORnot'].sum()/positive.loc[positive[positive.columns.values[i]] == 1][positive.columns.values[i]].sum()
    click_rate_neutral[i] = neutral.loc[neutral[neutral.columns.values[i]] == 1]['clickORnot'].sum()/neutral.loc[neutral[neutral.columns.values[i]] == 1][neutral.columns.values[i]].sum()
    click_rate_negative[i] = negative.loc[negative[negative.columns.values[i]] == 1]['clickORnot'].sum()/negative.loc[negative[negative.columns.values[i]] == 1][negative.columns.values[i]].sum()
for i in range(24):
    df_middleage_positive = df_middleage_positive.append(pd.DataFrame({'type':[x[i]],'Sentiment':['positive'],'click rate3':[click_rate_positive[i]]}),ignore_index = True)
    df_middleage_neutral= df_middleage_neutral.append(pd.DataFrame({'type':[x[i]],'Sentiment':['neutral'],'click rate3':[click_rate_neutral[i]]}),ignore_index = True)
    df_middleage_negative= df_middleage_negative.append(pd.DataFrame({'type':[x[i]],'Sentiment':['negative'],'click rate3':[click_rate_negative[i]]}),ignore_index = True)
df_middleage = pd.concat([df_middleage_positive, df_middleage_neutral,df_middleage_negative])

# %%
df_senior_positive = pd.DataFrame(columns=['type','Sentiment', 'click rate4'])
df_senior_neutral = pd.DataFrame(columns=['type','Sentiment', 'click rate4'])
df_senior_negative = pd.DataFrame(columns=['type', 'Sentiment','click rate4'])
df_prod_type_click_sentiment_age = pd.concat([df_prod_type_click_sentiment,df_age],axis=1)
df_diff_senior =df_prod_type_click_sentiment_age.loc[df_prod_type_click_sentiment_age['age_group'] == 'senior']


positive = df_diff_senior[df_diff_senior['Sentiment']== 'positive'] 
neutral = df_diff_senior[df_diff_senior['Sentiment']== 'neutral'] 
negative = df_diff_senior[df_diff_senior['Sentiment']== 'negative'] 

warnings.simplefilter(action='ignore', category=FutureWarning)

click_rate_positive = np.zeros(24)
click_rate_neutral = np.zeros(24)
click_rate_negative = np.zeros(24)
for i in range(24):
    click_rate_positive[i] = positive.loc[positive[positive.columns.values[i]] == 1]['clickORnot'].sum()/positive.loc[positive[positive.columns.values[i]] == 1][positive.columns.values[i]].sum()
    click_rate_neutral[i] = neutral.loc[neutral[neutral.columns.values[i]] == 1]['clickORnot'].sum()/neutral.loc[neutral[neutral.columns.values[i]] == 1][neutral.columns.values[i]].sum()
    click_rate_negative[i] = negative.loc[negative[negative.columns.values[i]] == 1]['clickORnot'].sum()/negative.loc[negative[negative.columns.values[i]] == 1][negative.columns.values[i]].sum()
for i in range(24):
    df_senior_positive = df_senior_positive.append(pd.DataFrame({'type':[x[i]],'Sentiment':['positive'],'click rate4':[click_rate_positive[i]]}),ignore_index = True)
    df_senior_neutral= df_senior_neutral.append(pd.DataFrame({'type':[x[i]],'Sentiment':['neutral'],'click rate4':[click_rate_neutral[i]]}),ignore_index = True)
    df_senior_negative= df_senior_negative.append(pd.DataFrame({'type':[x[i]],'Sentiment':['negative'],'click rate4':[click_rate_negative[i]]}),ignore_index = True)
df_senior = pd.concat([df_senior_positive, df_senior_neutral,df_senior_negative])

# %%
df_merge_age1 = pd.merge(df_juvenile,df_young, on=['type','Sentiment'], how="left",validate='one_to_one')
df_merge_age2 = pd.merge(df_merge_age1, df_middleage, on=['type','Sentiment'], how="left",validate='one_to_one')
df_merge_age = pd.merge(df_merge_age2, df_senior, on=['type','Sentiment'], how="left",validate='one_to_one')

# %%
df_merge_age['average_clickrate'] = 0
for i in range(72):
    df_merge_age['average_clickrate'][i] = (df_merge_age.iloc[i,2] + df_merge_age.iloc[i,3] + df_merge_age.iloc[i,4] + df_merge_age.iloc[i,5])/4

# %%
df_age_diff_1 = pd.DataFrame(columns=['diff 1'])
for i in range(72):
    if (df_merge_age.iloc[i,2] - df_merge_age.iloc[i,6])/(df_merge_age.iloc[i,2] + df_merge_age.iloc[i,6]) > 0.05:
        df_age_diff_1 = df_age_diff_1.append(pd.DataFrame({'diff 1':[1]}),ignore_index = True)
    elif (df_merge_age.iloc[i,2] - df_merge_age.iloc[i,6])/(df_merge_age.iloc[i,2] + df_merge_age.iloc[i,6]) < -0.05:
        df_age_diff_1 = df_age_diff_1.append(pd.DataFrame({'diff 1':[0.1]}),ignore_index = True)
    else:
        df_age_diff_1 = df_age_diff_1.append(pd.DataFrame({'diff 1':[0]}),ignore_index = True)

df_age_diff_2 = pd.DataFrame(columns=['diff 2'])
for i in range(72):
    if (df_merge_age.iloc[i,3] - df_merge_age.iloc[i,6])/(df_merge_age.iloc[i,3] + df_merge_age.iloc[i,6]) > 0.05:
        df_age_diff_2 = df_age_diff_2.append(pd.DataFrame({'diff 2':[1]}),ignore_index = True)
    elif (df_merge_age.iloc[i,3] - df_merge_age.iloc[i,6])/(df_merge_age.iloc[i,3] + df_merge_age.iloc[i,6]) < -0.05:
        df_age_diff_2 = df_age_diff_2.append(pd.DataFrame({'diff 2':[0.1]}),ignore_index = True)
    else:
        df_age_diff_2 = df_age_diff_2.append(pd.DataFrame({'diff 2':[0]}),ignore_index = True)

df_age_diff_3 = pd.DataFrame(columns=['diff 3'])
for i in range(72):
    if (df_merge_age.iloc[i,4] - df_merge_age.iloc[i,6])/(df_merge_age.iloc[i,4] + df_merge_age.iloc[i,6]) > 0.05:
        df_age_diff_3 = df_age_diff_3.append(pd.DataFrame({'diff 3':[1]}),ignore_index = True)
    elif (df_merge_age.iloc[i,4] - df_merge_age.iloc[i,6])/(df_merge_age.iloc[i,4] + df_merge_age.iloc[i,6]) < -0.05:
        df_age_diff_3 = df_age_diff_3.append(pd.DataFrame({'diff 3':[0.1]}),ignore_index = True)
    else:
        df_age_diff_3 = df_age_diff_3.append(pd.DataFrame({'diff 3':[0]}),ignore_index = True)
        
df_age_diff_4 = pd.DataFrame(columns=['diff 4'])
for i in range(72):
    if (df_merge_age.iloc[i,5] - df_merge_age.iloc[i,6])/(df_merge_age.iloc[i,5] + df_merge_age.iloc[i,6]) > 0.05:
        df_age_diff_4 = df_age_diff_4.append(pd.DataFrame({'diff 4':[1]}),ignore_index = True)
    elif (df_merge_age.iloc[i,5] - df_merge_age.iloc[i,6])/(df_merge_age.iloc[i,5] + df_merge_age.iloc[i,6]) < -0.05:
        df_age_diff_4 = df_age_diff_4.append(pd.DataFrame({'diff 4':[0.1]}),ignore_index = True)
    else:
        df_age_diff_4 = df_age_diff_4.append(pd.DataFrame({'diff 4':[0]}),ignore_index = True)
df_merge_age_diff_1 = pd.concat([df_age_diff_1, df_age_diff_2],axis = 1)
df_merge_age_diff_2 = pd.concat([df_merge_age_diff_1, df_age_diff_3],axis = 1)
df_merge_age_diff_3 = pd.concat([df_merge_age_diff_2, df_age_diff_4],axis = 1)
df_merge_age_diff_3['final'] = 0
for i in range(72):
    df_merge_age_diff_3['final'][i] = df_merge_age_diff_3.iloc[i,0] + df_merge_age_diff_3.iloc[i,1] + df_merge_age_diff_3.iloc[i,2] + df_merge_age_diff_3.iloc[i,3]
df_merge_age_diff_3
df_merge_age_diff_3['final sign'] = 0
for i in range(72):
    if df_merge_age_diff_3.iloc[i,4] >1 and df_merge_age_diff_3.iloc[i,4] % 1 >0:
        df_merge_age_diff_3['final sign'][i] = 'yes'
    else:
        df_merge_age_diff_3['final sign'][i] = 'no'
df_merge_age['significant'] = 0
for i in range(72):
    df_merge_age['significant'][i] = df_merge_age_diff_3.iloc[i,5]
df_merge_age
# Out:
#                   type Sentiment  click rate1  click rate2  click rate3  \
# 0              blender  positive     0.320000     0.461538     0.297872
# 1                  car  positive     0.050000     0.187500     0.106383
# 2               coffee  positive     0.048780     0.290323     0.361111
# 3             computer  positive     0.517647     0.648936     0.557895
# 4                dryer  positive     0.350000     0.348837     0.179487
# 5   elliptical trainer  positive     0.411765     0.363636     0.277778
# 6           face cream  positive     0.500000     0.571429     0.687500
# 7            furniture  positive     0.121212     0.405405     0.343750
# 8                jeans  positive     0.428571     0.558824     0.441176
# 9             lipstick  positive     0.692308     0.870968     0.807692
# 10              makeup  positive     0.090909     0.428571     0.133333
# 11               pants  positive     0.166667     0.333333     0.307692
# 12             perfume  positive     0.459016     0.514706     0.512500
# 13     pressure cooker  positive     0.750000     0.909091     0.565217
# 14        refrigerator  positive     0.392857     0.434783     0.333333
# 15      rowing machine  positive     0.050000     0.714286     0.409091
# 16              shaver  positive     0.294118     0.480000     0.368421
# 17            speakers  positive     0.388889     0.675676     0.370370
# 18              tablet  positive     0.473684     0.500000     0.400000
# 19          television  positive     0.472222     0.666667     0.488372
# 20           treadmill  positive     0.411765     0.550000     0.722222
# 21             vitamin  positive     0.000000     0.347826     0.125000
# 22              washer  positive     0.626667     0.812500     0.549296
# 23       women's purse  positive     0.500000     0.423077     0.358974
# 24             blender   neutral     0.313725     0.316667     0.300000
# 25                 car   neutral     0.571429     0.523810     0.484848
# 26              coffee   neutral     0.357143     0.333333     0.323529
# 27            computer   neutral     0.531915     0.584158     0.565217
# 28               dryer   neutral     0.745098     0.757576     0.690476
# 29  elliptical trainer   neutral     0.842105     0.750000     0.866667
# 30          face cream   neutral     0.941176     1.000000     0.857143
# 31           furniture   neutral     0.444444     0.666667     0.513514
# 32               jeans   neutral     0.580645     0.653061     0.577778
# 33            lipstick   neutral     0.425000     0.551724     0.441176
# 34              makeup   neutral     0.285714     0.450000     0.227273
# 35               pants   neutral     0.636364     0.777778     1.000000
# 36             perfume   neutral     0.556818     0.694444     0.540984
# 37     pressure cooker   neutral     0.900000     0.812500     0.909091
# 38        refrigerator   neutral     0.300000     0.482759     0.272727
# 39      rowing machine   neutral     0.000000     0.142857     0.176471
# 40              shaver   neutral     0.695652     0.736842     0.535714
# 41            speakers   neutral     0.692308     0.755556     0.666667
# 42              tablet   neutral     0.523810     0.653846     0.750000
# 43          television   neutral     0.656250     0.666667     0.763158
# 44           treadmill   neutral     0.520000     0.578947     0.650000
# 45             vitamin   neutral     0.857143     0.826087     0.777778
# 46              washer   neutral     0.466667     0.566667     0.431034
# 47       women's purse   neutral     0.714286     0.750000     0.483871
# 48             blender  negative     0.750000     0.803279     0.738462
# 49                 car  negative     0.382353     0.361111     0.404762
# 50              coffee  negative     0.428571     0.448276     0.580645
# 51            computer  negative     0.504673     0.468085     0.559524
# 52               dryer  negative     0.289474     0.454545     0.266667
# 53  elliptical trainer  negative     0.500000     0.500000     0.437500
# 54          face cream  negative     0.947368     0.900000     0.937500
# 55           furniture  negative     0.809524     0.793103     0.870968
# 56               jeans  negative     0.333333     0.262295     0.184615
# 57            lipstick  negative     0.695652     0.656250     0.608696
# 58              makeup  negative     0.100000     0.058824     0.200000
# 59               pants  negative     0.692308     0.882353     0.904762
# 60             perfume  negative     0.525641     0.516667     0.564706
# 61     pressure cooker  negative     0.000000     0.000000     0.000000
# 62        refrigerator  negative     0.166667     0.040000     0.117647
# 63      rowing machine  negative     0.190476     0.333333     0.050000
# 64              shaver  negative     0.560976     0.607143     0.551724
# 65            speakers  negative     0.333333     0.263158     0.466667
# 66              tablet  negative     0.333333     0.428571     0.347826
# 67          television  negative     0.405405     0.276596     0.297297
# 68           treadmill  negative     0.388889     0.333333     0.291667
# 69             vitamin  negative     0.900000     0.857143     0.750000
# 70              washer  negative     0.430769     0.421053     0.269841
# 71       women's purse  negative     0.571429     0.324324     0.424242
#
#     click rate4  average_clickrate significant
# 0      0.428571           0.376996         yes
# 1      0.322581           0.166616         yes
# 2      0.303030           0.250811         yes
# 3      0.693182           0.604415         yes
# 4      0.350000           0.307081         yes
# 5      0.333333           0.346628         yes
# 6      0.588235           0.586791         yes
# 7      0.222222           0.273147         yes
# 8      0.606557           0.508782         yes
# 9      0.923077           0.823511         yes
# 10     0.307692           0.240127         yes
# 11     0.428571           0.309066         yes
# 12     0.621951           0.527043         yes
# 13     0.764706           0.747254         yes
# 14     0.176471           0.334361         yes
# 15     0.111111           0.321122         yes
# 16     0.560000           0.425635         yes
# 17     0.684211           0.529786         yes
# 18     0.571429           0.486278         yes
# 19     0.720930           0.587048         yes
# 20     0.550000           0.558497         yes
# 21     0.210526           0.170838         yes
# 22     0.617647           0.651527         yes
# 23     0.583333           0.466346         yes
# 24     0.418182           0.337143         yes
# 25     0.720930           0.575254         yes
# 26     0.428571           0.360644         yes
# 27     0.602410           0.570925          no
# 28     0.750000           0.735787          no
# 29     0.466667           0.731360         yes
# 30     0.928571           0.931723          no
# 31     0.666667           0.572823         yes
# 32     0.632653           0.611034          no
# 33     0.678571           0.524118         yes
# 34     0.545455           0.377110         yes
# 35     0.818182           0.808081         yes
# 36     0.646341           0.609647         yes
# 37     0.833333           0.863731          no
# 38     0.473684           0.382293         yes
# 39     0.250000           0.142332         yes
# 40     0.684211           0.663105         yes
# 41     0.680000           0.698632          no
# 42     0.578947           0.626651         yes
# 43     0.711111           0.699296          no
# 44     0.600000           0.587237         yes
# 45     0.789474           0.812620          no
# 46     0.610169           0.518634         yes
# 47     0.782609           0.682691         yes
# 48     0.672727           0.741117          no
# 49     0.416667           0.391223          no
# 50     0.428571           0.471516          no
# 51     0.476190           0.502118          no
# 52     0.282609           0.323324         yes
# 53     0.545455           0.495739          no
# 54     0.823529           0.902099          no
# 55     0.820513           0.823527          no
# 56     0.285714           0.266490         yes
# 57     0.807692           0.692073         yes
# 58     0.105263           0.116022         yes
# 59     0.812500           0.822981          no
# 60     0.615385           0.555600          no
# 61     0.000000           0.000000          no
# 62     0.166667           0.122745         yes
# 63     0.333333           0.226786         yes
# 64     0.370370           0.522553         yes
# 65     0.360000           0.355789         yes
# 66     0.433333           0.385766         yes
# 67     0.311111           0.322602         yes
# 68     0.272727           0.321654         yes
# 69     0.833333           0.835119          no
# 70     0.388060           0.377431         yes
# 71     0.264706           0.396175         yes

# %% [markdown]
# # <center> Task 13

# %% [markdown]
# Based on your results make your recommendations. These should be in the form:
# - a. Based on our analysis (give details of your analysis), ads for such and such product are most likely to produce clicks in such and sentiment context (or state that we see no correlation between click rate of an ad for a product and the sentiment context of the ad)
# - b. Based on our analysis (with details), ads for such and such product are most likely to produce clicks in such and sentiment context by viewers of such and such gender (or state that we see no correlation between click rate of an ad for a product and the sentiment context of the ad and the gender of the viewer).
# - c.  Based on our analysis (with details), ads for such and such product are most likely to produce clicks in such and sentiment context by viewers of such and such age-group (or state that we see no correlation between click rate of an ad for a product and the sentiment context of the ad and the age-group of the viewer).  (15)

# %% [markdown]
# # <center> Answer

# %% [markdown]
# Prof. Pradhan said 'For question 13: The recommendations are meant to be for specific products (not product types). After all, the client wants to know how to spend the ad budget for specific products. But your analysis in questions 11 and 12 are for specific product types. Here you have to make the assumption that if the analysis applies to a product type, then it applies to each product under that product type. That is, a recommendation you would make for a product type would also apply to each product under that type, even if the click rates for the product type are not true for each product. In submitting your recommendations, in the interest of brevity you can choose just one product for each product type.'

# %% [markdown]
# # <center> Answer to 13(a)

# %% [markdown]
# ## A recommendation you would make for a product type would also apply to each product under that type.---- Prof. Pradhan

# %% [markdown]
# - For a specific product type, we can claculate the click rate for each sentiment type
#     - I define the "degree of difference" as:
# ## <center>degree of difference $= \frac{|clickrate\ (type\ a)\ -\ average\ clickrate|}{clickrate\ (type\ a)\ +\ average\ clickrate} $</center>
# - And then, for each product type, I add up the degree of difference of the three types of sentiment and pick the top ten product type. And  I choose just one product for each product type.

# %% [markdown]
# ### TOP 10
# - InstantPot pressure cooker - ads for InstantPot pressure cooker are most likely to produce clicks in neutral and positive context - pressure cooker
#
#
# - Centrum MultiVitamins - ads for Centrum MultiVitamins are most likely to produce clicks in negative and neutral context - vitamin
#
#
# - Maytag refrigerator - ads for Maytag refrigerator are most likely to produce clicks in neutral context - refrigerator
#
#
# - Tesla - ads for Tesla are most likely to produce clicks in neutral context - car
#
#
# - Maytag dryer - ads for Maytag dryer are most likely to produce clicks in neutral context - dryer
#
#
# - Covergirl makeup - ads for Covergirl makeup are most likely to produce clicks in neutral context - makeup
#
#
# - Docker pants	- ads for Docker pants are most likely to produce clicks in negative and neutral context - pants
#
#
# - Broyhill recliner - ads for Broyhill recliner are most likely to produce clicks in negative context - furniture
#
#
# - NemoK blender - ads for NemoK blender are most likely to produce clicks in negative context - blender
#
#
# - Lee jeans - ads for Lee jeans	 are most likely to produce clicks in neutral context - jeans

# %%
df_10['average_clickrate'] = 0
for i in range(24):
    df_10['average_clickrate'][i] = (df_10.iloc[i,1] + df_10.iloc[i,2] + df_10.iloc[i,3])/3
df_10_diff_1 = pd.DataFrame(columns=['diff 1'])
for i in range(24):
    df_10_diff_1 = df_10_diff_1.append(pd.DataFrame({'diff 1':[abs(df_10.iloc[i,1] - df_10.iloc[i,4])/(df_10.iloc[i,1] + df_10.iloc[i,4])]}),ignore_index = True)

df_10_diff_2 = pd.DataFrame(columns=['diff 2'])
for i in range(24):
    df_10_diff_2 = df_10_diff_2.append(pd.DataFrame({'diff 2':[abs(df_10.iloc[i,2] - df_10.iloc[i,4])/(df_10.iloc[i,2] + df_10.iloc[i,4])]}),ignore_index = True)

df_10_diff_3 = pd.DataFrame(columns=['diff 3'])
for i in range(24):
    df_10_diff_3 = df_10_diff_3.append(pd.DataFrame({'diff 3':[abs(df_10.iloc[i,3] - df_10.iloc[i,4])/(df_10.iloc[i,3] + df_10.iloc[i,4])]}),ignore_index = True)
        
df_merge_10_diff_1 = pd.concat([df_10_diff_1, df_10_diff_2],axis = 1)
df_merge_10_diff_2 = pd.concat([df_merge_10_diff_1, df_10_diff_3],axis = 1)
df_10['diff']=0
for i in range(24):
    df_10['diff'][i] = df_merge_10_diff_2.iloc[i,0] + df_merge_10_diff_2.iloc[i,1] + df_merge_10_diff_2.iloc[i,2]
df_10.sort_values("diff",inplace=True,ignore_index = True, ascending = False)
df_10.head(10)
# Out:
#               type  negative_click_rate  neutral_click_rate  \
# 0  pressure cooker             0.000000            0.864407
# 1          vitamin             0.835294            0.814815
# 2     refrigerator             0.122222            0.388889
# 3              car             0.391892            0.581699
# 4            dryer             0.323699            0.734568
# 5           makeup             0.112676            0.384615
# 6            pants             0.835821            0.818182
# 7        furniture             0.825000            0.578947
# 8          blender             0.742739            0.337963
# 9            jeans             0.264822            0.609756
#
#    positive_click_rate  average_clickrate      diff
# 0             0.714286           0.526231  1.394775
# 1             0.186667           0.612259  0.828721
# 2             0.347368           0.286160  0.650228
# 3             0.156627           0.376739  0.646248
# 4             0.308642           0.455636  0.595981
# 5             0.245283           0.247525  0.595787
# 6             0.333333           0.662445  0.551407
# 7             0.279070           0.561006  0.541818
# 8             0.378788           0.486496  0.513093
# 9             0.509881           0.461487  0.459003

# %%
df_13 = df_real[['product_type','product', 'Sentiment', 'clickORnot']]
df_13.groupby(['product_type','product', 'Sentiment']).apply(lambda x: x.sum()/len(x))
# Out:
#                                                          clickORnot
# product_type       product                    Sentiment
# blender            Hamilton Beach blender     negative     0.671642
#                                               neutral      0.353846
#                                               positive     0.216216
#                    NemoK blender              negative     0.978261
#                                               neutral      0.325843
#                                               positive     0.317460
#                    Vitamix blender            negative     0.536585
#                                               neutral      0.338710
#                                               positive     0.639344
# car                Ford  sedan                negative     0.013158
#                                               neutral      0.125000
#                                               positive     0.265823
#                    Tesla                      negative     0.791667
#                                               neutral      0.987654
#                                               positive     0.057471
# coffee             Lavazza Coffee             negative     0.840909
#                                               neutral      0.447368
#                                               positive     0.342857
#                    Starbucks Coffee           negative     0.300000
#                                               neutral      0.323529
#                                               positive     0.207547
# computer           Apple computer             negative     0.700000
#                                               neutral      0.923077
#                                               positive     0.764706
#                    Apple laptop               negative     0.153846
#                                               neutral      0.725000
#                                               positive     0.772727
#                    Dell computer              negative     0.830986
#                                               neutral      0.382353
#                                               positive     0.719512
#                    Dell laptop                negative     0.145299
#                                               neutral      0.357143
#                                               positive     0.452830
#                    Lenova laptop              negative     0.750000
#                                               neutral      0.718310
#                                               positive     0.419355
# dryer              LG dryer                   negative     0.680851
#                                               neutral      0.791667
#                                               positive     0.395349
#                    Maytag dryer               negative     0.117647
#                                               neutral      0.704918
#                                               positive     0.256757
#                    Samsung dryer              negative     0.275862
#                                               neutral      0.716981
#                                               positive     0.311111
# elliptical trainer NordicTrack elliptical     negative     0.491228
#                                               neutral      0.737705
#                                               positive     0.344828
# face cream         Clinique moisturizer       negative     0.902778
#                                               neutral      0.930556
#                                               positive     0.583333
# furniture          Broyhill recliner          negative     0.814286
#                                               neutral      0.562500
#                                               positive     0.242857
#                    Ikea sofa                  negative     0.840000
#                                               neutral      0.594203
#                                               positive     0.322034
# jeans              Cougar jeans               negative     0.083333
#                                               neutral      0.311688
#                                               positive     0.390000
#                    Lee jeans                  negative     0.342466
#                                               neutral      0.777778
#                                               positive     0.328947
#                    Levis Jeans                negative     0.404762
#                                               neutral      0.800000
#                                               positive     0.844156
# lipstick           Maybelline lipstick        negative     0.885246
#                                               neutral      0.209877
#                                               positive     0.698413
#                    covergirl lipstick         negative     0.418605
#                                               neutral      1.000000
#                                               positive     1.000000
# makeup             Covergirl makeup           negative     0.112676
#                                               neutral      0.384615
#                                               positive     0.245283
# pants              Docker pants               negative     0.835821
#                                               neutral      0.818182
#                                               positive     0.333333
# perfume            BasilBasel perfume         negative     0.771429
#                                               neutral      0.864407
#                                               positive     0.366667
#                    Giorgio perfume            negative     0.638554
#                                               neutral      0.969697
#                                               positive     0.830769
#                    Givenchy perfume           negative     0.757576
#                                               neutral      0.302632
#                                               positive     0.347826
#                    Guess perfume              negative     0.172414
#                                               neutral      0.306452
#                                               positive     0.788462
#                    Jaguar perfume             negative     0.434783
#                                               neutral      0.700000
#                                               positive     0.311111
# pressure cooker    InstantPot pressure cooker negative     0.000000
#                                               neutral      0.864407
#                                               positive     0.714286
# refrigerator       Haier refrigerator         negative     0.173077
#                                               neutral      0.166667
#                                               positive     0.283019
#                    Maytag refrigerator        negative     0.052632
#                                               neutral      0.722222
#                                               positive     0.428571
# rowing machine     NordicTrack rower          negative     0.200000
#                                               neutral      0.142857
#                                               positive     0.297297
# shaver             Gillette shaver            negative     0.904762
#                                               neutral      0.960784
#                                               positive     0.139535
#                    Remington shaver           negative     0.145161
#                                               neutral      0.236842
#                                               positive     0.744186
# speakers           Soundwave speakers         negative     0.119403
#                                               neutral      0.955224
#                                               positive     0.561644
#                    bose speakers              negative     0.596774
#                                               neutral      0.463768
#                                               positive     0.523077
# tablet             Apple iPad                 negative     0.391304
#                                               neutral      0.627907
#                                               positive     0.500000
# television         LG TV                      negative     0.298507
#                                               neutral      0.590909
#                                               positive     0.644444
#                    Samsung TV                 negative     0.666667
#                                               neutral      0.823529
#                                               positive     0.703125
#                    Sony TV                    negative     0.055556
#                                               neutral      0.678571
#                                               positive     0.431034
# treadmill          NordicTrack treadmill      negative     0.316456
#                                               neutral      0.584270
#                                               positive     0.560000
# vitamin            Centrum MultiVitamins      negative     0.835294
#                                               neutral      0.814815
#                                               positive     0.186667
# washer             LG washer                  negative     0.153846
#                                               neutral      0.516667
#                                               positive     0.828947
#                    Maytag washer              negative     0.922222
#                                               neutral      0.361702
#                                               positive     0.278846
#                    Samsung washer             negative     0.000000
#                                               neutral      0.698795
#                                               positive     0.897959
# women's purse      Coach purse                negative     0.316456
#                                               neutral      0.453333
#                                               positive     0.400000
#                    Kaai handbags              negative     0.490566
#                                               neutral      0.956522
#                                               positive     0.512821

# %% [markdown]
# # <center> Answer to 13(b)

# %% [markdown]
# ## A recommendation you would make for a product type would also apply to each product under that type.---- Prof. Pradhan

# %% [markdown]
# - For a specific product type and sentiment, we can claculate the click rate for each gender type
#     - I define the "degree of difference" as:
# ## <center>degree of difference $= \frac{|clickrate\ (gender\ a)\ -\ average\ clickrate|}{clickrate\ (gender\ a)\ +\ average\ clickrate} $</center>
# - And then, I pick the top ten product type. And  I choose just one product for each product type.

# %% [markdown]
# ### TOP 10
# - Centrum MultiVitamins - ads for Centrum MultiVitamins are most likely to produce clicks in positive context by viewers of female - vitamin
#
#
# - NordicTrack elliptical - ads for NordicTrack elliptical are most likely to produce clicks in positive context by viewers of male - elliptical trainer
#
#
# - Docker pants	- ads for Docker pants are most likely to produce clicks in positive context by viewers of female - pants
#
#
# - Remington shaver - ads for Remington shaver are most likely to produce clicks in positive context by viewers of male - shaver
#
#
# - NordicTrack rower - ads for NordicTrack rower are most likely to produce clicks in positive context by viewers of female - rowing machine
#
#
# - Maytag refrigerator - ads for Maytag refrigerator are most likely to produce clicks in positive context by viewers of female - refrigerator
#
#
# - Samsung dryer - ads for Samsung dryer are most likely to produce clicks in positive context by viewers of male - dryer
#
#
# - Covergirl makeup - ads for Covergirl makeup are most likely to produce clicks in positive context by viewers of female - makeup
#
#
# - Tesla - ads for Tesla are most likely to produce clicks in positive context by viewers of male - car
#
#
# - Apple iPad - ads for Apple iPad are most likely to produce clicks in positive context by viewers of female - tablet

# %%
df_merge_gender['diff'] = 0
for i in range(24):
    df_merge_gender['diff'][i] = abs(df_merge_gender.iloc[i,2] - df_merge_gender.iloc[i,3])/(df_merge_gender.iloc[i,2] + df_merge_gender.iloc[i,3]+0.00001)
df_merge_gender.sort_values("diff",inplace=True,ignore_index = True, ascending = False)   
df_merge_gender.head(10)
# Out:
#                  type Sentiment  click rate (male)  click rate (female)  \
# 0             vitamin  positive           0.108108             0.263158
# 1  elliptical trainer  positive           0.424242             0.240000
# 2               pants  positive           0.238095             0.416667
# 3              shaver  positive           0.518519             0.312500
# 4      rowing machine  positive           0.218750             0.357143
# 5        refrigerator  positive           0.250000             0.406780
# 6               dryer  positive           0.372093             0.236842
# 7              makeup  positive           0.205882             0.315789
# 8                 car  positive           0.183908             0.126582
# 9              tablet  positive           0.428571             0.568182
#
#        diff
# 0  0.417613
# 1  0.277368
# 2  0.272723
# 3  0.247908
# 4  0.240306
# 5  0.238706
# 6  0.222107
# 7  0.210678
# 8  0.184624
# 9  0.140064

# %%
df_13b = df_real[['product_type','product', 'Sentiment', 'gender','clickORnot']]
df_13b.groupby(['product_type','product', 'Sentiment','gender']).apply(lambda x: x.sum()/len(x))
# Out:
#                                                                 clickORnot
# product_type       product                    Sentiment gender
# blender            Hamilton Beach blender     negative  female    0.645161
#                                                         male      0.694444
#                                               neutral   female    0.425000
#                                                         male      0.240000
#                                               positive  female    0.189189
#                                                         male      0.243243
#                    NemoK blender              negative  female    0.948718
#                                                         male      1.000000
#                                               neutral   female    0.352941
#                                                         male      0.289474
#                                               positive  female    0.242424
#                                                         male      0.400000
#                    Vitamix blender            negative  female    0.511111
#                                                         male      0.567568
#                                               neutral   female    0.344828
#                                                         male      0.333333
#                                               positive  female    0.694444
#                                                         male      0.560000
# car                Ford  sedan                negative  female    0.000000
#                                                         male      0.024390
#                                               neutral   female    0.121951
#                                                         male      0.129032
#                                               positive  female    0.230769
#                                                         male      0.300000
#                    Tesla                      negative  female    0.827586
#                                                         male      0.767442
#                                               neutral   female    1.000000
#                                                         male      0.978261
#                                               positive  female    0.025000
#                                                         male      0.085106
# coffee             Lavazza Coffee             negative  female    0.900000
#                                                         male      0.791667
#                                               neutral   female    0.347826
#                                                         male      0.600000
#                                               positive  female    0.428571
#                                                         male      0.285714
#                    Starbucks Coffee           negative  female    0.326087
#                                                         male      0.277778
#                                               neutral   female    0.400000
#                                                         male      0.250000
#                                               positive  female    0.224490
#                                                         male      0.192982
# computer           Apple computer             negative  female    0.666667
#                                                         male      0.729730
#                                               neutral   female    0.937500
#                                                         male      0.909091
#                                               positive  female    0.800000
#                                                         male      0.727273
#                    Apple laptop               negative  female    0.250000
#                                                         male      0.000000
#                                               neutral   female    0.777778
#                                                         male      0.681818
#                                               positive  female    0.708333
#                                                         male      0.850000
#                    Dell computer              negative  female    0.846154
#                                                         male      0.812500
#                                               neutral   female    0.394737
#                                                         male      0.366667
#                                               positive  female    0.659091
#                                                         male      0.789474
#                    Dell laptop                negative  female    0.147541
#                                                         male      0.142857
#                                               neutral   female    0.402778
#                                                         male      0.296296
#                                               positive  female    0.450980
#                                                         male      0.454545
#                    Lenova laptop              negative  female    0.764706
#                                                         male      0.736842
#                                               neutral   female    0.593750
#                                                         male      0.820513
#                                               positive  female    0.459459
#                                                         male      0.360000
# dryer              LG dryer                   negative  female    0.750000
#                                                         male      0.629630
#                                               neutral   female    0.782609
#                                                         male      0.800000
#                                               positive  female    0.300000
#                                                         male      0.478261
#                    Maytag dryer               negative  female    0.111111
#                                                         male      0.125000
#                                               neutral   female    0.700000
#                                                         male      0.709677
#                                               positive  female    0.243243
#                                                         male      0.270270
#                    Samsung dryer              negative  female    0.300000
#                                                         male      0.250000
#                                               neutral   female    0.741935
#                                                         male      0.681818
#                                               positive  female    0.157895
#                                                         male      0.423077
# elliptical trainer NordicTrack elliptical     negative  female    0.448276
#                                                         male      0.535714
#                                               neutral   female    0.718750
#                                                         male      0.758621
#                                               positive  female    0.240000
#                                                         male      0.424242
# face cream         Clinique moisturizer       negative  female    0.886364
#                                                         male      0.928571
#                                               neutral   female    0.916667
#                                                         male      0.944444
#                                               positive  female    0.550000
#                                                         male      0.625000
# furniture          Broyhill recliner          negative  female    0.868421
#                                                         male      0.750000
#                                               neutral   female    0.588235
#                                                         male      0.533333
#                                               positive  female    0.258065
#                                                         male      0.230769
#                    Ikea sofa                  negative  female    0.814815
#                                                         male      0.869565
#                                               neutral   female    0.685714
#                                                         male      0.500000
#                                               positive  female    0.258065
#                                                         male      0.392857
# jeans              Cougar jeans               negative  female    0.092593
#                                                         male      0.071429
#                                               neutral   female    0.303030
#                                                         male      0.318182
#                                               positive  female    0.372881
#                                                         male      0.414634
#                    Lee jeans                  negative  female    0.300000
#                                                         male      0.393939
#                                               neutral   female    0.777778
#                                                         male      0.777778
#                                               positive  female    0.325581
#                                                         male      0.333333
#                    Levis Jeans                negative  female    0.422222
#                                                         male      0.384615
#                                               neutral   female    0.781250
#                                                         male      0.818182
#                                               positive  female    0.861111
#                                                         male      0.829268
# lipstick           Maybelline lipstick        negative  female    0.812500
#                                                         male      0.965517
#                                               neutral   female    0.227273
#                                                         male      0.189189
#                                               positive  female    0.607143
#                                                         male      0.771429
#                    covergirl lipstick         negative  female    0.428571
#                                                         male      0.409091
#                                               neutral   female    1.000000
#                                                         male      1.000000
#                                               positive  female    1.000000
#                                                         male      1.000000
# makeup             Covergirl makeup           negative  female    0.119048
#                                                         male      0.103448
#                                               neutral   female    0.270270
#                                                         male      0.487805
#                                               positive  female    0.315789
#                                                         male      0.205882
# pants              Docker pants               negative  female    0.866667
#                                                         male      0.810811
#                                               neutral   female    0.842105
#                                                         male      0.800000
#                                               positive  female    0.416667
#                                                         male      0.238095
# perfume            BasilBasel perfume         negative  female    0.750000
#                                                         male      0.800000
#                                               neutral   female    0.880000
#                                                         male      0.852941
#                                               positive  female    0.312500
#                                                         male      0.428571
#                    Giorgio perfume            negative  female    0.619048
#                                                         male      0.658537
#                                               neutral   female    0.969697
#                                                         male      0.969697
#                                               positive  female    0.900000
#                                                         male      0.771429
#                    Givenchy perfume           negative  female    0.763158
#                                                         male      0.750000
#                                               neutral   female    0.352941
#                                                         male      0.261905
#                                               positive  female    0.297297
#                                                         male      0.406250
#                    Guess perfume              negative  female    0.125000
#                                                         male      0.205882
#                                               neutral   female    0.382353
#                                                         male      0.214286
#                                               positive  female    0.818182
#                                                         male      0.766667
#                    Jaguar perfume             negative  female    0.333333
#                                                         male      0.500000
#                                               neutral   female    0.772727
#                                                         male      0.611111
#                                               positive  female    0.391304
#                                                         male      0.227273
# pressure cooker    InstantPot pressure cooker negative  female    0.000000
#                                                         male      0.000000
#                                               neutral   female    0.933333
#                                                         male      0.793103
#                                               positive  female    0.742857
#                                                         male      0.678571
# refrigerator       Haier refrigerator         negative  female    0.242424
#                                                         male      0.052632
#                                               neutral   female    0.238095
#                                                         male      0.121212
#                                               positive  female    0.310345
#                                                         male      0.250000
#                    Maytag refrigerator        negative  female    0.105263
#                                                         male      0.000000
#                                               neutral   female    0.695652
#                                                         male      0.769231
#                                               positive  female    0.500000
#                                                         male      0.250000
# rowing machine     NordicTrack rower          negative  female    0.250000
#                                                         male      0.151515
#                                               neutral   female    0.115385
#                                                         male      0.173913
#                                               positive  female    0.357143
#                                                         male      0.218750
# shaver             Gillette shaver            negative  female    0.970588
#                                                         male      0.827586
#                                               neutral   female    1.000000
#                                                         male      0.904762
#                                               positive  female    0.100000
#                                                         male      0.173913
#                    Remington shaver           negative  female    0.115385
#                                                         male      0.166667
#                                               neutral   female    0.166667
#                                                         male      0.300000
#                                               positive  female    0.666667
#                                                         male      0.774194
# speakers           Soundwave speakers         negative  female    0.151515
#                                                         male      0.088235
#                                               neutral   female    0.945946
#                                                         male      0.966667
#                                               positive  female    0.600000
#                                                         male      0.526316
#                    bose speakers              negative  female    0.458333
#                                                         male      0.684211
#                                               neutral   female    0.454545
#                                                         male      0.472222
#                                               positive  female    0.600000
#                                                         male      0.400000
# tablet             Apple iPad                 negative  female    0.404255
#                                                         male      0.377778
#                                               neutral   female    0.566038
#                                                         male      0.727273
#                                               positive  female    0.568182
#                                                         male      0.428571
# television         LG TV                      negative  female    0.387097
#                                                         male      0.222222
#                                               neutral   female    0.571429
#                                                         male      0.608696
#                                               positive  female    0.666667
#                                                         male      0.619048
#                    Samsung TV                 negative  female    0.640000
#                                                         male      0.700000
#                                               neutral   female    0.857143
#                                                         male      0.800000
#                                               positive  female    0.696970
#                                                         male      0.709677
#                    Sony TV                    negative  female    0.045455
#                                                         male      0.062500
#                                               neutral   female    0.794118
#                                                         male      0.500000
#                                               positive  female    0.454545
#                                                         male      0.400000
# treadmill          NordicTrack treadmill      negative  female    0.365854
#                                                         male      0.263158
#                                               neutral   female    0.577778
#                                                         male      0.590909
#                                               positive  female    0.485714
#                                                         male      0.625000
# vitamin            Centrum MultiVitamins      negative  female    0.875000
#                                                         male      0.800000
#                                               neutral   female    0.872340
#                                                         male      0.735294
#                                               positive  female    0.263158
#                                                         male      0.108108
# washer             LG washer                  negative  female    0.250000
#                                                         male      0.071429
#                                               neutral   female    0.600000
#                                                         male      0.457143
#                                               positive  female    0.782609
#                                                         male      0.900000
#                    Maytag washer              negative  female    0.923077
#                                                         male      0.921569
#                                               neutral   female    0.380000
#                                                         male      0.340909
#                                               positive  female    0.298246
#                                                         male      0.255319
#                    Samsung washer             negative  female    0.000000
#                                                         male      0.000000
#                                               neutral   female    0.615385
#                                                         male      0.772727
#                                               positive  female    0.933333
#                                                         male      0.867925
# women's purse      Coach purse                negative  female    0.250000
#                                                         male      0.384615
#                                               neutral   female    0.371429
#                                                         male      0.525000
#                                               positive  female    0.463415
#                                                         male      0.323529
#                    Kaai handbags              negative  female    0.560000
#                                                         male      0.428571
#                                               neutral   female    0.964286
#                                                         male      0.951220
#                                               positive  female    0.461538
#                                                         male      0.564103

# %% [markdown]
# # <center> Answer to 13(c)

# %% [markdown]
# ## A recommendation you would make for a product type would also apply to each product under that type.---- Prof. Pradhan

# %% [markdown]
# - For a specific product type and sentiment, we can claculate the click rate for each gender type
#     - I define the "degree of difference" as: $i = 1,2,3,4$
# ## <center>degree of difference $= \frac{|clickrate\ (age\ i)\ -\ average\ clickrate|}{clickrate\ (age\ i)\ +\ average\ clickrate} $</center>
# - And then, for each product type, I add up the degree of difference of the four types of age and pick the top ten product type. And  I choose just one product for each product type.

# %% [markdown]
# ### TOP 10
# - NordicTrack rower - ads for NordicTrack rower are most likely to produce clicks in positive context by viewers of young - rowing machine
#
#
# - Centrum MultiVitamins - ads for Centrum MultiVitamins are most likely to produce clicks in positive context by viewers of young - vitamin
#
#
# - Covergirl makeup - ads for Covergirl makeup are most likely to produce clicks in positive context by viewers of young - makeup
#
#
# - Ford sedan - ads for Ford sedan are most likely to produce clicks in positive context by viewers of senior - car
#
#
# - Lavazza Coffee - ads for Lavazza Coffee are most likely to produce clicks in positive context by viewers of middle-age - coffee
#
#
# - Maytag refrigerator - ads for Maytag refrigerator are most likely to produce clicks in negative context by viewers of senior - refrigerator
#
#
# - Broyhill recliner - ads for Broyhill recliner are most likely to produce clicks in positive context by viewers of young - furniture
#
#
# - Covergirl makeup - ads for Covergirl makeup are most likely to produce clicks in neutral context by viewers of senior - makeup
#
#
# - bose speakers - ads for bose speakers are most likely to produce clicks in positive context by viewers of young - speakers
#
#
# - Kaai handbags - ads for Kaai handbags are most likely to produce clicks in negative context by viewers of juvenile - women's purse

# %%
def diff(s1, s2):
    return abs(s1-s2)/(s1+s2)
df_merge_age['diff'] = 0
for i in range(72):
    df_merge_age['diff'][i] = diff(df_merge_age.iloc[i,2],df_merge_age.iloc[i,6])+diff(df_merge_age.iloc[i,3],df_merge_age.iloc[i,6])+diff(df_merge_age.iloc[i,4],df_merge_age.iloc[i,6])+diff(df_merge_age.iloc[i,5],df_merge_age.iloc[i,6])
df_merge_age.sort_values("diff",inplace=True,ignore_index = True, ascending = False) 
df_merge_age.head(15)
# Out:
#               type Sentiment  click rate1  click rate2  click rate3  \
# 0   rowing machine  positive     0.050000     0.714286     0.409091
# 1          vitamin  positive     0.000000     0.347826     0.125000
# 2   rowing machine   neutral     0.000000     0.142857     0.176471
# 3           makeup  positive     0.090909     0.428571     0.133333
# 4              car  positive     0.050000     0.187500     0.106383
# 5   rowing machine  negative     0.190476     0.333333     0.050000
# 6           coffee  positive     0.048780     0.290323     0.361111
# 7     refrigerator  negative     0.166667     0.040000     0.117647
# 8        furniture  positive     0.121212     0.405405     0.343750
# 9           makeup  negative     0.100000     0.058824     0.200000
# 10          makeup   neutral     0.285714     0.450000     0.227273
# 11        speakers  positive     0.388889     0.675676     0.370370
# 12    refrigerator  positive     0.392857     0.434783     0.333333
# 13   women's purse  negative     0.571429     0.324324     0.424242
# 14    refrigerator   neutral     0.300000     0.482759     0.272727
#
#     click rate4  average_clickrate significant      diff
# 0      0.111111           0.321122         yes  1.716610
# 1      0.210526           0.170838         yes  1.600250
# 2      0.250000           0.142332         yes  1.383357
# 3      0.307692           0.240127         yes  1.141860
# 4      0.322581           0.166616         yes  1.136781
# 5      0.333333           0.226786         yes  1.106175
# 6      0.303030           0.250811         yes  1.021907
# 7      0.166667           0.122745         yes  0.833164
# 8      0.222222           0.273147         yes  0.797433
# 9      0.105263           0.116022         yes  0.715657
# 10     0.545455           0.377110         yes  0.656407
# 11     0.684211           0.529786         yes  0.578695
# 12     0.176471           0.334361         yes  0.521625
# 13     0.264706           0.396175         yes  0.513986
# 14     0.473684           0.382293         yes  0.510790

# %%
df_13c = df_real[['product_type','product', 'Sentiment', 'age_group','clickORnot']]
df_13c.groupby(['product_type','product', 'Sentiment','age_group']).apply(lambda x: x.sum()/len(x))
# Out:
#                                                                     clickORnot
# product_type       product                    Sentiment age_group
# blender            Hamilton Beach blender     negative  juvenile      0.533333
#                                                         middle-age    0.650000
#                                                         senior        0.750000
#                                                         young         0.750000
#                                               neutral   juvenile      0.153846
#                                                         middle-age    0.352941
#                                                         senior        0.500000
#                                                         young         0.368421
#                                               positive  juvenile      0.235294
#                                                         middle-age    0.136364
#                                                         senior        0.235294
#                                                         young         0.277778
#                    NemoK blender              negative  juvenile      0.952381
#                                                         middle-age    1.000000
#                                                         senior        0.954545
#                                                         young         1.000000
#                                               neutral   juvenile      0.300000
#                                                         middle-age    0.363636
#                                                         senior        0.363636
#                                                         young         0.280000
#                                               positive  juvenile      0.210526
#                                                         middle-age    0.333333
#                                                         senior        0.333333
#                                                         young         0.411765
#                    Vitamix blender            negative  juvenile      0.708333
#                                                         middle-age    0.545455
#                                                         senior        0.235294
#                                                         young         0.578947
#                                               neutral   juvenile      0.444444
#                                                         middle-age    0.090909
#                                                         senior        0.411765
#                                                         young         0.312500
#                                               positive  juvenile      0.571429
#                                                         middle-age    0.538462
#                                                         senior        0.705882
#                                                         young         0.705882
# car                Ford  sedan                negative  juvenile      0.000000
#                                                         middle-age    0.000000
#                                                         senior        0.052632
#                                                         young         0.000000
#                                               neutral   juvenile      0.000000
#                                                         middle-age    0.000000
#                                                         senior        0.400000
#                                                         young         0.050000
#                                               positive  juvenile      0.100000
#                                                         middle-age    0.227273
#                                                         senior        0.562500
#                                                         young         0.238095
#                    Tesla                      negative  juvenile      0.812500
#                                                         middle-age    0.772727
#                                                         senior        0.823529
#                                                         young         0.764706
#                                               neutral   juvenile      1.000000
#                                                         middle-age    1.000000
#                                                         senior        1.000000
#                                                         young         0.954545
#                                               positive  juvenile      0.000000
#                                                         middle-age    0.000000
#                                                         senior        0.066667
#                                                         young         0.148148
# coffee             Lavazza Coffee             negative  juvenile      0.800000
#                                                         middle-age    0.888889
#                                                         senior        0.923077
#                                                         young         0.750000
#                                               neutral   juvenile      0.416667
#                                                         middle-age    0.230769
#                                                         senior        0.500000
#                                                         young         1.000000
#                                               positive  juvenile      0.181818
#                                                         middle-age    0.500000
#                                                         senior        0.416667
#                                                         young         0.333333
#                    Starbucks Coffee           negative  juvenile      0.280000
#                                                         middle-age    0.454545
#                                                         senior        0.250000
#                                                         young         0.235294
#                                               neutral   juvenile      0.333333
#                                                         middle-age    0.380952
#                                                         senior        0.400000
#                                                         young         0.225806
#                                               positive  juvenile      0.000000
#                                                         middle-age    0.333333
#                                                         senior        0.238095
#                                                         young         0.280000
# computer           Apple computer             negative  juvenile      0.562500
#                                                         middle-age    0.789474
#                                                         senior        0.714286
#                                                         young         0.714286
#                                               neutral   juvenile      0.857143
#                                                         middle-age    0.954545
#                                                         senior        1.000000
#                                                         young         0.866667
#                                               positive  juvenile      0.625000
#                                                         middle-age    0.687500
#                                                         senior        0.937500
#                                                         young         0.800000
#                    Apple laptop               negative  juvenile      0.166667
#                                                         middle-age    0.000000
#                                                         senior        0.307692
#                                                         young         0.076923
#                                               neutral   juvenile      0.714286
#                                                         middle-age    0.875000
#                                                         senior        0.777778
#                                                         young         0.555556
#                                               positive  juvenile      0.666667
#                                                         middle-age    0.833333
#                                                         senior        1.000000
#                                                         young         0.692308
#                    Dell computer              negative  juvenile      0.909091
#                                                         middle-age    0.941176
#                                                         senior        0.705882
#                                                         young         0.733333
#                                               neutral   juvenile      0.357143
#                                                         middle-age    0.300000
#                                                         senior        0.538462
#                                                         young         0.380952
#                                               positive  juvenile      0.631579
#                                                         middle-age    0.680000
#                                                         senior        0.750000
#                                                         young         0.833333
#                    Dell laptop                negative  juvenile      0.179487
#                                                         middle-age    0.153846
#                                                         senior        0.153846
#                                                         young         0.076923
#                                               neutral   juvenile      0.363636
#                                                         middle-age    0.241379
#                                                         senior        0.259259
#                                                         young         0.513514
#                                               positive  juvenile      0.350000
#                                                         middle-age    0.392857
#                                                         senior        0.545455
#                                                         young         0.480000
#                    Lenova laptop              negative  juvenile      0.708333
#                                                         middle-age    0.800000
#                                                         senior        0.714286
#                                                         young         0.789474
#                                               neutral   juvenile      0.578947
#                                                         middle-age    0.846154
#                                                         senior        0.750000
#                                                         young         0.736842
#                                               positive  juvenile      0.388889
#                                                         middle-age    0.285714
#                                                         senior        0.500000
#                                                         young         0.500000
# dryer              LG dryer                   negative  juvenile      0.692308
#                                                         middle-age    0.700000
#                                                         senior        0.555556
#                                                         young         0.733333
#                                               neutral   juvenile      0.736842
#                                                         middle-age    0.700000
#                                                         senior        0.777778
#                                                         young         1.000000
#                                               positive  juvenile      0.300000
#                                                         middle-age    0.333333
#                                                         senior        0.454545
#                                                         young         0.437500
#                    Maytag dryer               negative  juvenile      0.066667
#                                                         middle-age    0.130435
#                                                         senior        0.111111
#                                                         young         0.166667
#                                               neutral   juvenile      0.812500
#                                                         middle-age    0.750000
#                                                         senior        0.727273
#                                                         young         0.500000
#                                               positive  juvenile      0.409091
#                                                         middle-age    0.136364
#                                                         senior        0.285714
#                                                         young         0.111111
#                    Samsung dryer              negative  juvenile      0.100000
#                                                         middle-age    0.166667
#                                                         senior        0.315789
#                                                         young         0.411765
#                                               neutral   juvenile      0.687500
#                                                         middle-age    0.583333
#                                                         senior        0.750000
#                                                         young         0.888889
#                                               positive  juvenile      0.250000
#                                                         middle-age    0.181818
#                                                         senior        0.375000
#                                                         young         0.388889
# elliptical trainer NordicTrack elliptical     negative  juvenile      0.500000
#                                                         middle-age    0.437500
#                                                         senior        0.545455
#                                                         young         0.500000
#                                               neutral   juvenile      0.842105
#                                                         middle-age    0.866667
#                                                         senior        0.466667
#                                                         young         0.750000
#                                               positive  juvenile      0.411765
#                                                         middle-age    0.277778
#                                                         senior        0.333333
#                                                         young         0.363636
# face cream         Clinique moisturizer       negative  juvenile      0.947368
#                                                         middle-age    0.937500
#                                                         senior        0.823529
#                                                         young         0.900000
#                                               neutral   juvenile      0.941176
#                                                         middle-age    0.857143
#                                                         senior        0.928571
#                                                         young         1.000000
#                                               positive  juvenile      0.500000
#                                                         middle-age    0.687500
#                                                         senior        0.588235
#                                                         young         0.571429
# furniture          Broyhill recliner          negative  juvenile      0.857143
#                                                         middle-age    0.842105
#                                                         senior        0.791667
#                                                         young         0.769231
#                                               neutral   juvenile      0.466667
#                                                         middle-age    0.647059
#                                                         senior        0.588235
#                                                         young         0.533333
#                                               positive  juvenile      0.000000
#                                                         middle-age    0.222222
#                                                         senior        0.200000
#                                                         young         0.384615
#                    Ikea sofa                  negative  juvenile      0.714286
#                                                         middle-age    0.916667
#                                                         senior        0.866667
#                                                         young         0.812500
#                                               neutral   juvenile      0.416667
#                                                         middle-age    0.400000
#                                                         senior        0.736842
#                                                         young         0.777778
#                                               positive  juvenile      0.181818
#                                                         middle-age    0.500000
#                                                         senior        0.250000
#                                                         young         0.454545
# jeans              Cougar jeans               negative  juvenile      0.200000
#                                                         middle-age    0.115385
#                                                         senior        0.034483
#                                                         young         0.000000
#                                               neutral   juvenile      0.333333
#                                                         middle-age    0.187500
#                                                         senior        0.400000
#                                                         young         0.320000
#                                               positive  juvenile      0.370370
#                                                         middle-age    0.346154
#                                                         senior        0.409091
#                                                         young         0.440000
#                    Lee jeans                  negative  juvenile      0.545455
#                                                         middle-age    0.222222
#                                                         senior        0.285714
#                                                         young         0.391304
#                                               neutral   juvenile      0.619048
#                                                         middle-age    0.933333
#                                                         senior        0.666667
#                                                         young         1.000000
#                                               positive  juvenile      0.200000
#                                                         middle-age    0.238095
#                                                         senior        0.533333
#                                                         young         0.360000
#                    Levis Jeans                negative  juvenile      0.346154
#                                                         middle-age    0.238095
#                                                         senior        0.650000
#                                                         young         0.411765
#                                               neutral   juvenile      0.800000
#                                                         middle-age    0.642857
#                                                         senior        0.789474
#                                                         young         1.000000
#                                               positive  juvenile      0.785714
#                                                         middle-age    0.761905
#                                                         senior        0.833333
#                                                         young         1.000000
# lipstick           Maybelline lipstick        negative  juvenile      0.923077
#                                                         middle-age    0.769231
#                                                         senior        0.944444
#                                                         young         0.882353
#                                               neutral   juvenile      0.115385
#                                                         middle-age    0.050000
#                                                         senior        0.470588
#                                                         young         0.277778
#                                               positive  juvenile      0.466667
#                                                         middle-age    0.722222
#                                                         senior        0.875000
#                                                         young         0.714286
#                    covergirl lipstick         negative  juvenile      0.400000
#                                                         middle-age    0.400000
#                                                         senior        0.500000
#                                                         young         0.400000
#                                               neutral   juvenile      1.000000
#                                                         middle-age    1.000000
#                                                         senior        1.000000
#                                                         young         1.000000
#                                               positive  juvenile      1.000000
#                                                         middle-age    1.000000
#                                                         senior        1.000000
#                                                         young         1.000000
# makeup             Covergirl makeup           negative  juvenile      0.100000
#                                                         middle-age    0.200000
#                                                         senior        0.105263
#                                                         young         0.058824
#                                               neutral   juvenile      0.285714
#                                                         middle-age    0.227273
#                                                         senior        0.545455
#                                                         young         0.450000
#                                               positive  juvenile      0.090909
#                                                         middle-age    0.133333
#                                                         senior        0.307692
#                                                         young         0.428571
# pants              Docker pants               negative  juvenile      0.692308
#                                                         middle-age    0.904762
#                                                         senior        0.812500
#                                                         young         0.882353
#                                               neutral   juvenile      0.636364
#                                                         middle-age    1.000000
#                                                         senior        0.818182
#                                                         young         0.777778
#                                               positive  juvenile      0.166667
#                                                         middle-age    0.307692
#                                                         senior        0.428571
#                                                         young         0.333333
# perfume            BasilBasel perfume         negative  juvenile      0.750000
#                                                         middle-age    0.928571
#                                                         senior        0.750000
#                                                         young         0.400000
#                                               neutral   juvenile      0.857143
#                                                         middle-age    0.846154
#                                                         senior        0.818182
#                                                         young         0.928571
#                                               positive  juvenile      0.416667
#                                                         middle-age    0.333333
#                                                         senior        0.437500
#                                                         young         0.285714
#                    Giorgio perfume            negative  juvenile      0.714286
#                                                         middle-age    0.560000
#                                                         senior        0.761905
#                                                         young         0.500000
#                                               neutral   juvenile      0.950000
#                                                         middle-age    0.928571
#                                                         senior        1.000000
#                                                         young         1.000000
#                                               positive  juvenile      0.750000
#                                                         middle-age    0.894737
#                                                         senior        0.944444
#                                                         young         0.666667
#                    Givenchy perfume           negative  juvenile      0.650000
#                                                         middle-age    0.722222
#                                                         senior        0.800000
#                                                         young         0.888889
#                                               neutral   juvenile      0.217391
#                                                         middle-age    0.090909
#                                                         senior        0.428571
#                                                         young         0.357143
#                                               positive  juvenile      0.285714
#                                                         middle-age    0.117647
#                                                         senior        0.500000
#                                                         young         0.437500
#                    Guess perfume              negative  juvenile      0.000000
#                                                         middle-age    0.187500
#                                                         senior        0.357143
#                                                         young         0.166667
#                                               neutral   juvenile      0.133333
#                                                         middle-age    0.187500
#                                                         senior        0.555556
#                                                         young         0.307692
#                                               positive  juvenile      0.833333
#                                                         middle-age    0.812500
#                                                         senior        0.785714
#                                                         young         0.750000
#                    Jaguar perfume             negative  juvenile      0.538462
#                                                         middle-age    0.416667
#                                                         senior        0.416667
#                                                         young         0.333333
#                                               neutral   juvenile      0.555556
#                                                         middle-age    0.714286
#                                                         senior        0.750000
#                                                         young         0.750000
#                                               positive  juvenile      0.153846
#                                                         middle-age    0.300000
#                                                         senior        0.416667
#                                                         young         0.400000
# pressure cooker    InstantPot pressure cooker negative  juvenile      0.000000
#                                                         middle-age    0.000000
#                                                         senior        0.000000
#                                                         young         0.000000
#                                               neutral   juvenile      0.900000
#                                                         middle-age    0.909091
#                                                         senior        0.833333
#                                                         young         0.812500
#                                               positive  juvenile      0.750000
#                                                         middle-age    0.565217
#                                                         senior        0.764706
#                                                         young         0.909091
# refrigerator       Haier refrigerator         negative  juvenile      0.333333
#                                                         middle-age    0.222222
#                                                         senior        0.176471
#                                                         young         0.058824
#                                               neutral   juvenile      0.000000
#                                                         middle-age    0.000000
#                                                         senior        0.357143
#                                                         young         0.285714
#                                               positive  juvenile      0.352941
#                                                         middle-age    0.400000
#                                                         senior        0.111111
#                                                         young         0.166667
#                    Maytag refrigerator        negative  juvenile      0.066667
#                                                         middle-age    0.000000
#                                                         senior        0.142857
#                                                         young         0.000000
#                                               neutral   juvenile      0.750000
#                                                         middle-age    0.750000
#                                                         senior        0.800000
#                                                         young         0.666667
#                                               positive  juvenile      0.454545
#                                                         middle-age    0.250000
#                                                         senior        0.250000
#                                                         young         0.727273
# rowing machine     NordicTrack rower          negative  juvenile      0.190476
#                                                         middle-age    0.050000
#                                                         senior        0.333333
#                                                         young         0.333333
#                                               neutral   juvenile      0.000000
#                                                         middle-age    0.176471
#                                                         senior        0.250000
#                                                         young         0.142857
#                                               positive  juvenile      0.050000
#                                                         middle-age    0.409091
#                                                         senior        0.111111
#                                                         young         0.714286
# shaver             Gillette shaver            negative  juvenile      0.909091
#                                                         middle-age    0.875000
#                                                         senior        0.900000
#                                                         young         0.933333
#                                               neutral   juvenile      0.866667
#                                                         middle-age    1.000000
#                                                         senior        1.000000
#                                                         young         1.000000
#                                               positive  juvenile      0.125000
#                                                         middle-age    0.166667
#                                                         senior        0.272727
#                                                         young         0.000000
#                    Remington shaver           negative  juvenile      0.157895
#                                                         middle-age    0.153846
#                                                         senior        0.058824
#                                                         young         0.230769
#                                               neutral   juvenile      0.375000
#                                                         middle-age    0.071429
#                                                         senior        0.333333
#                                                         young         0.285714
#                                               positive  juvenile      0.444444
#                                                         middle-age    0.714286
#                                                         senior        0.785714
#                                                         young         0.923077
# speakers           Soundwave speakers         negative  juvenile      0.050000
#                                                         middle-age    0.090909
#                                                         senior        0.181818
#                                                         young         0.160000
#                                               neutral   juvenile      0.941176
#                                                         middle-age    1.000000
#                                                         senior        0.928571
#                                                         young         0.958333
#                                               positive  juvenile      0.500000
#                                                         middle-age    0.375000
#                                                         senior        0.666667
#                                                         young         0.636364
#                    bose speakers              negative  juvenile      0.687500
#                                                         middle-age    0.684211
#                                                         senior        0.500000
#                                                         young         0.461538
#                                               neutral   juvenile      0.500000
#                                                         middle-age    0.400000
#                                                         senior        0.363636
#                                                         young         0.523810
#                                               positive  juvenile      0.318182
#                                                         middle-age    0.363636
#                                                         senior        0.705882
#                                                         young         0.733333
# tablet             Apple iPad                 negative  juvenile      0.333333
#                                                         middle-age    0.347826
#                                                         senior        0.433333
#                                                         young         0.428571
#                                               neutral   juvenile      0.523810
#                                                         middle-age    0.750000
#                                                         senior        0.578947
#                                                         young         0.653846
#                                               positive  juvenile      0.473684
#                                                         middle-age    0.400000
#                                                         senior        0.571429
#                                                         young         0.500000
# television         LG TV                      negative  juvenile      0.500000
#                                                         middle-age    0.100000
#                                                         senior        0.347826
#                                                         young         0.125000
#                                               neutral   juvenile      0.500000
#                                                         middle-age    0.714286
#                                                         senior        0.705882
#                                                         young         0.416667
#                                               positive  juvenile      0.300000
#                                                         middle-age    0.571429
#                                                         senior        0.750000
#                                                         young         0.833333
#                    Samsung TV                 negative  juvenile      0.714286
#                                                         middle-age    0.666667
#                                                         senior        0.555556
#                                                         young         0.714286
#                                               neutral   juvenile      0.833333
#                                                         middle-age    0.933333
#                                                         senior        0.714286
#                                                         young         0.800000
#                                               positive  juvenile      0.692308
#                                                         middle-age    0.526316
#                                                         senior        0.736842
#                                                         young         0.923077
#                    Sony TV                    negative  juvenile      0.083333
#                                                         middle-age    0.000000
#                                                         senior        0.076923
#                                                         young         0.058824
#                                               neutral   juvenile      0.583333
#                                                         middle-age    0.625000
#                                                         senior        0.714286
#                                                         young         0.785714
#                                               positive  juvenile      0.384615
#                                                         middle-age    0.411765
#                                                         senior        0.625000
#                                                         young         0.400000
# treadmill          NordicTrack treadmill      negative  juvenile      0.388889
#                                                         middle-age    0.291667
#                                                         senior        0.272727
#                                                         young         0.333333
#                                               neutral   juvenile      0.520000
#                                                         middle-age    0.650000
#                                                         senior        0.600000
#                                                         young         0.578947
#                                               positive  juvenile      0.411765
#                                                         middle-age    0.722222
#                                                         senior        0.550000
#                                                         young         0.550000
# vitamin            Centrum MultiVitamins      negative  juvenile      0.900000
#                                                         middle-age    0.750000
#                                                         senior        0.833333
#                                                         young         0.857143
#                                               neutral   juvenile      0.857143
#                                                         middle-age    0.777778
#                                                         senior        0.789474
#                                                         young         0.826087
#                                               positive  juvenile      0.000000
#                                                         middle-age    0.125000
#                                                         senior        0.210526
#                                                         young         0.347826
# washer             LG washer                  negative  juvenile      0.000000
#                                                         middle-age    0.086957
#                                                         senior        0.285714
#                                                         young         0.133333
#                                               neutral   juvenile      0.476190
#                                                         middle-age    0.454545
#                                                         senior        0.583333
#                                                         young         0.562500
#                                               positive  juvenile      0.800000
#                                                         middle-age    0.800000
#                                                         senior        0.823529
#                                                         young         0.894737
#                    Maytag washer              negative  juvenile      0.965517
#                                                         middle-age    0.882353
#                                                         senior        0.900000
#                                                         young         0.916667
#                                               neutral   juvenile      0.157895
#                                                         middle-age    0.321429
#                                                         senior        0.464286
#                                                         young         0.473684
#                                               positive  juvenile      0.214286
#                                                         middle-age    0.076923
#                                                         senior        0.393939
#                                                         young         0.470588
#                    Samsung washer             negative  juvenile      0.000000
#                                                         middle-age    0.000000
#                                                         senior        0.000000
#                                                         young         0.000000
#                                               neutral   juvenile      0.750000
#                                                         middle-age    0.578947
#                                                         senior        0.842105
#                                                         young         0.640000
#                                               positive  juvenile      0.925926
#                                                         middle-age    0.840000
#                                                         senior        0.833333
#                                                         young         0.964286
# women's purse      Coach purse                negative  juvenile      0.500000
#                                                         middle-age    0.312500
#                                                         senior        0.142857
#                                                         young         0.318182
#                                               neutral   juvenile      0.437500
#                                                         middle-age    0.222222
#                                                         senior        0.615385
#                                                         young         0.466667
#                                               positive  juvenile      0.250000
#                                                         middle-age    0.363636
#                                                         senior        0.529412
#                                                         young         0.392857
#                    Kaai handbags              negative  juvenile      0.750000
#                                                         middle-age    0.529412
#                                                         senior        0.461538
#                                                         young         0.333333
#                                               neutral   juvenile      0.947368
#                                                         middle-age    0.846154
#                                                         senior        1.000000
#                                                         young         1.000000
#                                               positive  juvenile      0.611111
#                                                         middle-age    0.352941
#                                                         senior        0.631579
#                                                         young         0.458333
